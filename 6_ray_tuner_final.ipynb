# %% [markdown]
# #### Applying Ray Tuner:
#
# A **Ray Tuner** refers to the hyperparameter tuning component of **Ray Tune**, a library in the **Ray** ecosystem that simplifies distributed hyperparameter tuning for machine learning models.
#
# Ray itself is a framework for building and running distributed applications, and Ray Tune is specifically designed to optimize model performance by efficiently exploring hyperparameter spaces.

# %%
import tensorflow_datasets as tfds
import logging
from zipfile import ZipFile
import os
import sys
import shutil
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
import os
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from PIL import Image
import torch
from torchvision import transforms
import torchvision
import shutil

# %%
# Custom dataset class
class ImageDataset(Dataset):
    def __init__(self, csv_file, img_dir, transform=None):
        self.data_frame = pd.read_csv(csv_file)
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.data_frame)

    def __getitem__(self, idx):
        img_name = os.path.join(self.img_dir, self.data_frame.iloc[idx, 0])
        image = Image.open(img_name)
        label = int(self.data_frame.iloc[idx, 1])

        if self.transform:
            image = self.transform(image)

        return image, label


# Load the CSV file
train_csv_file = '/kaggle/input/deepweeds-image-classification/train_subset0.csv'  # Replace with your actual path
test_csv_file = '/kaggle/input/deepweeds-image-classification/test_subset0.csv'  # Replace with your actual path
val_csv_file = '/kaggle/input/deepweeds-image-classification/val_subset0.csv'  # Replace with your actual path
img_dir = '/kaggle/input/deepweeds-image-classification/images'  # Replace with your images directory


# Image transformations (resize, normalization, etc.)
transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Resizing to 128x128, you can adjust this
    transforms.ToTensor(),  # Convert the image to PyTorch tensor
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
  ])


# Create the train and test datasets
train_dataset = ImageDataset(csv_file=train_csv_file, img_dir=img_dir, transform=transform)
test_dataset = ImageDataset(csv_file=test_csv_file, img_dir=img_dir, transform=transform)
val_dataset = ImageDataset(csv_file=val_csv_file, img_dir=img_dir, transform=transform)


# Create DataLoaders for batching
def create_dataloader(loader_type):
  if loader_type=='train':
    train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
    print(f"len train_loader {len(train_loader)}")
    return train_loader
  elif loader_type=='val':
    val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
    return val_loader
  else:
    test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)
    return test_loader

# %%
num_train_samples = len(train_dataset)
num_val_samples = len(val_dataset)
num_test_samples = len(test_dataset)
print(f"Number of training samples: {num_train_samples}")
print(f"Number of validation samples: {num_val_samples}")
print(f"Number of testing samples: {num_test_samples}")
# Out:
# Number of training samples: 10501
# Number of validation samples: 3501
# Number of testing samples: 3507

# %%
from torchvision import models
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# #####Example Workflow-
#
# In a typical Ray Tune setup:
#
# * You define a search space for your model’s hyperparameters (e.g., learning rate, batch size).
# * Specify a search algorithm (random search, grid search, etc.).
# * Use a scheduler (e.g., ASHA) for early stopping or adaptive resource allocation.
# * Ray Tune then launches trials, monitors their performance, and refines the search process to find the best set of hyperparameters.
#
# Ray Tune is especially useful for models that are computationally intensive, such as deep learning models, or when tuning must be done at scale.

# %%
# Install Ray

# !pip install ray
# Out:
# Requirement already satisfied: ray in /opt/conda/lib/python3.10/site-packages (2.24.0)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from ray) (8.1.7)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from ray) (3.15.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray) (4.22.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray) (1.0.8)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ray) (21.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray) (3.20.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray) (6.0.2)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray) (1.4.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ray) (2.32.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray) (0.18.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->ray) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->ray) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ray) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ray) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ray) (2024.8.30)

# %%
import ray
from ray import tune
from ray.tune.schedulers import ASHAScheduler
# Out:
# 2024-10-30 13:38:53,666	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2024-10-30 13:38:54,288	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %%
from ray import tune, train

# Training loop
def train_resnet50(config):
  model = models.resnet50(pretrained=True)
  num_ftrs = model.fc.in_features
  model.fc = nn.Linear(num_ftrs, 9)  # Adjust for CIFAR-10 (8 classes)

  # Set Up Loss Function and Optimizer
  criterion = nn.CrossEntropyLoss()

  if config["optimizer"] == "Adam":
        optimizer = optim.Adam(model.parameters(), lr=config["lr"])
  elif config["optimizer"] == "SGD":
        optimizer = optim.SGD(model.parameters(), lr=config["lr"], momentum=0.7)
  optimizer = optim.Adam(model.parameters(), lr=config["lr"])

  device = 'cuda' if torch.cuda.is_available() else 'cpu'
  model = model.to(device)

  train_loader = create_dataloader(loader_type='train')
  val_loader = create_dataloader(loader_type='val')

  for epoch in range(10):           # You can adjust the number of epochs
          model.train()
          running_loss = 0.0
          for i, (inputs, targets) in enumerate(train_loader):
              inputs, targets = inputs.to(device), targets.to(device)

              optimizer.zero_grad()
              outputs = model(inputs)
              loss = criterion(outputs, targets)
              loss.backward()
              optimizer.step()
              running_loss += loss.item()

              if i % 100 == 0:
                  print(f'Epoch [{epoch+1}/10], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')

          train_loss = running_loss / len(train_loader)

          model.eval()
          val_loss = 0.0
          val_correct = 0
          val_total = 0
          with torch.no_grad():
            for inputs, targets in val_loader:
              inputs, targets = inputs.to(device), targets.to(device)
              outputs = model(inputs)
              _, predicted = outputs.max(1)
              loss = criterion(outputs, predicted)

              val_loss += loss.item()
              val_total += targets.size(0)
              val_correct += predicted.eq(targets).sum().item()

          # Calculate accuracy
          val_loss /= len(val_loader)
          val_accuracy = val_correct / val_total
          print(f'Epoch [{epoch+1}/10], Validation Accuracy: {val_accuracy:.4f}')

          # Correct use of tune.report
          train.report(dict(
            loss=train_loss,
            val_loss=val_loss,
            val_accuracy=val_accuracy
        ))

# %%
# Define hyperparameter search space that Ray Tune will search:

search_space = {
    "lr": tune.choice([1e-3, 1e-1]),           # Log-uniform distribution for learning rate
    "optimizer": tune.choice(["Adam", "SGD"])      # Choose between Adam and SGD as the optimizer
}
ray.shutdown()
ray.init()
# Out:
# 2024-10-30 13:38:59,014	INFO worker.py:1753 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.14', ray_version='2.24.0', ray_commit='cfea8b29800afc76823bd1a171657010f4eb96bb')
# (train_resnet50 pid=372) /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
# (train_resnet50 pid=372)   warnings.warn(
# (train_resnet50 pid=372) /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
# (train_resnet50 pid=372)   warnings.warn(msg)
# (train_resnet50 pid=372) Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
#   7%|▋         | 6.88M/97.8M [00:00<00:01, 71.7MB/s]
#  91%|█████████▏| 89.2M/97.8M [00:00<00:00, 166MB/s]
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 151MB/s]
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 163MB/s]
# (train_resnet50 pid=372) len train_loader 657
# (train_resnet50 pid=372) Epoch [1/10], Step [1/657], Loss: 2.2258
# (train_resnet50 pid=373) len train_loader 657
# (train_resnet50 pid=372) Epoch [1/10], Step [101/657], Loss: 1.7381 [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (train_resnet50 pid=372) Epoch [1/10], Step [201/657], Loss: 2.1544 [repeated 2x across cluster]
# (train_resnet50 pid=373) Epoch [1/10], Step [301/657], Loss: 0.8693 [repeated 2x across cluster]
# (train_resnet50 pid=373) Epoch [1/10], Step [401/657], Loss: 1.4604 [repeated 2x across cluster]
# (train_resnet50 pid=373) Epoch [1/10], Step [501/657], Loss: 0.7192 [repeated 2x across cluster]
# (train_resnet50 pid=373) Epoch [1/10], Step [601/657], Loss: 1.2396 [repeated 2x across cluster]
# (train_resnet50 pid=372) Epoch [1/10], Validation Accuracy: 0.5201
# (train_resnet50 pid=372) Epoch [1/10], Step [601/657], Loss: 1.6157
# (train_resnet50 pid=372) Epoch [2/10], Step [1/657], Loss: 2.4986
# (train_resnet50 pid=373) Epoch [1/10], Validation Accuracy: 0.2559
# (train_resnet50 pid=372) Epoch [2/10], Step [101/657], Loss: 1.3733 [repeated 2x across cluster]
# (train_resnet50 pid=372) Epoch [2/10], Step [201/657], Loss: 1.8241 [repeated 2x across cluster]
# (train_resnet50 pid=372) Epoch [2/10], Step [301/657], Loss: 1.1756 [repeated 2x across cluster]
# (train_resnet50 pid=372) Epoch [2/10], Step [401/657], Loss: 1.5951 [repeated 2x across cluster]
# (train_resnet50 pid=372) Epoch [2/10], Step [501/657], Loss: 1.4037 [repeated 2x across cluster]
# (train_resnet50 pid=372) Epoch [2/10], Step [601/657], Loss: 2.1868 [repeated 2x across cluster]
# (train_resnet50 pid=372) Epoch [2/10], Validation Accuracy: 0.5213
# (train_resnet50 pid=373) Epoch [2/10], Step [601/657], Loss: 1.0426
# (train_resnet50 pid=373) Epoch [3/10], Step [1/657], Loss: 0.8431
# (train_resnet50 pid=522) /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead. [repeated 2x across cluster]
# (train_resnet50 pid=522)   warnings.warn( [repeated 2x across cluster]
# (train_resnet50 pid=522) /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights. [repeated 2x across cluster]
# (train_resnet50 pid=522)   warnings.warn(msg) [repeated 2x across cluster]
# (train_resnet50 pid=373) Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
#  79%|███████▉  | 77.5M/97.8M [00:00<00:00, 166MB/s] [repeated 9x across cluster]
# (train_resnet50 pid=522) len train_loader 657
# (train_resnet50 pid=373) Epoch [2/10], Validation Accuracy: 0.6133
# (train_resnet50 pid=522) Epoch [1/10], Step [1/657], Loss: 2.2264
# (train_resnet50 pid=522) Epoch [1/10], Step [101/657], Loss: 1.4222 [repeated 2x across cluster]
# (train_resnet50 pid=522) Epoch [1/10], Step [201/657], Loss: 1.8073 [repeated 2x across cluster]
# (train_resnet50 pid=522) Epoch [1/10], Step [301/657], Loss: 1.3499 [repeated 2x across cluster]
# (train_resnet50 pid=522) Epoch [1/10], Step [401/657], Loss: 1.4061 [repeated 2x across cluster]
# (train_resnet50 pid=522) Epoch [1/10], Step [501/657], Loss: 1.0853 [repeated 2x across cluster]
# (train_resnet50 pid=522) Epoch [1/10], Step [601/657], Loss: 1.0242 [repeated 2x across cluster]
# (train_resnet50 pid=373) Epoch [3/10], Validation Accuracy: 0.6718
# (train_resnet50 pid=373) Epoch [4/10], Step [1/657], Loss: 1.2395
# (train_resnet50 pid=522) Epoch [1/10], Validation Accuracy: 0.5567
# (train_resnet50 pid=522) Epoch [2/10], Step [1/657], Loss: 1.0821
# (train_resnet50 pid=373) Epoch [4/10], Step [101/657], Loss: 0.7074
# (train_resnet50 pid=522) Epoch [2/10], Step [101/657], Loss: 1.3761
# (train_resnet50 pid=522) Epoch [2/10], Step [201/657], Loss: 1.3278 [repeated 2x across cluster]
# (train_resnet50 pid=373) Epoch [4/10], Step [301/657], Loss: 1.1634
# (train_resnet50 pid=522) Epoch [2/10], Step [301/657], Loss: 0.7417
# (train_resnet50 pid=373) Epoch [4/10], Step [401/657], Loss: 0.8049
# (train_resnet50 pid=522) Epoch [2/10], Step [401/657], Loss: 0.7912
# (train_resnet50 pid=522) Epoch [2/10], Step [501/657], Loss: 1.0803 [repeated 2x across cluster]
# (train_resnet50 pid=373) Epoch [4/10], Step [601/657], Loss: 0.6583
# (train_resnet50 pid=522) Epoch [2/10], Step [601/657], Loss: 1.1194
# (train_resnet50 pid=373) Epoch [4/10], Validation Accuracy: 0.7158
# (train_resnet50 pid=522) Epoch [3/10], Step [1/657], Loss: 1.3544
# (train_resnet50 pid=522) Epoch [3/10], Step [101/657], Loss: 1.1291
# (train_resnet50 pid=522) Epoch [2/10], Validation Accuracy: 0.6135
# (train_resnet50 pid=522) Epoch [3/10], Step [201/657], Loss: 1.1773
# (train_resnet50 pid=522) Epoch [3/10], Step [301/657], Loss: 0.9021
# (train_resnet50 pid=522) Epoch [3/10], Step [401/657], Loss: 0.7677
# (train_resnet50 pid=522) Epoch [3/10], Step [501/657], Loss: 0.5559
# (train_resnet50 pid=522) Epoch [3/10], Step [601/657], Loss: 1.3586
# (train_resnet50 pid=522) Epoch [3/10], Validation Accuracy: 0.6095
# (train_resnet50 pid=522) Epoch [4/10], Step [1/657], Loss: 0.8084
# (train_resnet50 pid=522) Epoch [4/10], Step [101/657], Loss: 0.6436
# (train_resnet50 pid=522) Epoch [4/10], Step [201/657], Loss: 1.2380
# (train_resnet50 pid=522) Epoch [4/10], Step [301/657], Loss: 0.6602
# (train_resnet50 pid=522) Epoch [4/10], Step [401/657], Loss: 1.1533
# (train_resnet50 pid=522) Epoch [4/10], Step [501/657], Loss: 0.8707
# (train_resnet50 pid=522) Epoch [4/10], Step [601/657], Loss: 0.9045
# (train_resnet50 pid=522) Epoch [4/10], Validation Accuracy: 0.6141

# %%
#  Set Up the Scheduler and Search Algorithm:

#We'll use 'ASHAScheduler' for early stopping and resource-efficient search
scheduler = ASHAScheduler(
    metric="loss",  # Metric to optimize
    mode="min",         # Maximize accuracy
    max_t=4,           # Max number of training epochs
    grace_period=1,     # Allow at least 1 epoch before early stopping
    reduction_factor=2  # Halve resources after each iteration
)

# %%
# Run Ray Tune Tuning:

#We'll invoke Ray Tune to start the hyperparameter tuning
analysis = tune.run(
    train_resnet50,  # The training function
    resources_per_trial={"cpu": 2, "gpu": 1},  # Adjust according to your hardware
    config=search_space,  # The hyperparameter search space
    num_samples=3,
    scheduler=scheduler,
    progress_reporter=tune.CLIReporter(
        metric_columns=["loss", "val_loss", "val_accuracy"]
    )
)
# Out:
# 2024-10-30 13:39:00,360	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# == Status ==
# Current time: 2024-10-30 13:39:08 (running for 00:00:00.28)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 0/4 CPUs, 0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (3 PENDING)
# +----------------------------+----------+-------+-------+-------------+
# | Trial name                 | status   | loc   |    lr | optimizer   |
# |----------------------------+----------+-------+-------+-------------|
# | train_resnet50_51ec7_00000 | PENDING  |       | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | PENDING  |       | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |       | 0.001 | SGD         |
# +----------------------------+----------+-------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:39:14 (running for 00:00:05.36)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (3 PENDING)
# +----------------------------+----------+-------+-------+-------------+
# | Trial name                 | status   | loc   |    lr | optimizer   |
# |----------------------------+----------+-------+-------+-------------|
# | train_resnet50_51ec7_00000 | PENDING  |       | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | PENDING  |       | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |       | 0.001 | SGD         |
# +----------------------------+----------+-------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:39:19 (running for 00:00:10.43)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:39:24 (running for 00:00:15.47)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:39:29 (running for 00:00:20.53)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:39:34 (running for 00:00:25.57)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:39:39 (running for 00:00:30.62)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:39:44 (running for 00:00:35.65)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:39:49 (running for 00:00:40.70)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:39:54 (running for 00:00:45.73)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:39:59 (running for 00:00:50.78)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:04 (running for 00:00:55.82)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:09 (running for 00:01:00.86)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:14 (running for 00:01:05.90)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:19 (running for 00:01:10.94)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:24 (running for 00:01:15.98)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:29 (running for 00:01:21.03)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:34 (running for 00:01:26.07)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:39 (running for 00:01:31.11)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:44 (running for 00:01:36.14)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:49 (running for 00:01:41.19)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:54 (running for 00:01:46.23)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:40:59 (running for 00:01:51.27)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:41:05 (running for 00:01:56.31)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:41:10 (running for 00:02:01.35)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:41:15 (running for 00:02:06.39)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:41:20 (running for 00:02:11.43)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:41:25 (running for 00:02:16.47)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:41:30 (running for 00:02:21.51)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:41:35 (running for 00:02:26.55)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:41:40 (running for 00:02:31.59)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:41:45 (running for 00:02:36.62)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:41:50 (running for 00:02:41.66)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |
# |----------------------------+----------+----------------+-------+-------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |
# +----------------------------+----------+----------------+-------+-------------+
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                </th><th style="text-align: right;">    loss</th><th style="text-align: right;">  val_accuracy</th><th style="text-align: right;">  val_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>train_resnet50_51ec7_00000</td><td style="text-align: right;">1.56989 </td><td style="text-align: right;">      0.52128 </td><td style="text-align: right;">  0.694207</td></tr>
# <tr><td>train_resnet50_51ec7_00001</td><td style="text-align: right;">0.783039</td><td style="text-align: right;">      0.715795</td><td style="text-align: right;">  0.313103</td></tr>
# <tr><td>train_resnet50_51ec7_00002</td><td style="text-align: right;">0.954701</td><td style="text-align: right;">      0.61411 </td><td style="text-align: right;">  0.416708</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# == Status ==
# Current time: 2024-10-30 13:41:55 (running for 00:02:46.71)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.5959437289012985
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |    loss |   val_loss |   val_accuracy |
# |----------------------------+----------+----------------+-------+-------------+---------+------------+----------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         | 1.91762 |   0.493062 |       0.520137 |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         | 1.27427 |   0.234808 |       0.255927 |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |         |            |                |
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:42:00 (running for 00:02:51.76)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.5959437289012985
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |    loss |   val_loss |   val_accuracy |
# |----------------------------+----------+----------------+-------+-------------+---------+------------+----------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         | 1.91762 |   0.493062 |       0.520137 |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         | 1.27427 |   0.234808 |       0.255927 |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |         |            |                |
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:42:05 (running for 00:02:56.81)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.5959437289012985
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |    loss |   val_loss |   val_accuracy |
# |----------------------------+----------+----------------+-------+-------------+---------+------------+----------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         | 1.91762 |   0.493062 |       0.520137 |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         | 1.27427 |   0.234808 |       0.255927 |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |         |            |                |
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:42:10 (running for 00:03:01.86)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.5959437289012985
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |    loss |   val_loss |   val_accuracy |
# |----------------------------+----------+----------------+-------+-------------+---------+------------+----------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         | 1.91762 |   0.493062 |       0.520137 |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         | 1.27427 |   0.234808 |       0.255927 |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |         |            |                |
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:42:15 (running for 00:03:06.90)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.5959437289012985
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |    loss |   val_loss |   val_accuracy |
# |----------------------------+----------+----------------+-------+-------------+---------+------------+----------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         | 1.91762 |   0.493062 |       0.520137 |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         | 1.27427 |   0.234808 |       0.255927 |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |         |            |                |
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:42:20 (running for 00:03:11.95)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.5959437289012985
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |    loss |   val_loss |   val_accuracy |
# |----------------------------+----------+----------------+-------+-------------+---------+------------+----------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         | 1.91762 |   0.493062 |       0.520137 |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         | 1.27427 |   0.234808 |       0.255927 |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |         |            |                |
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:42:25 (running for 00:03:16.99)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.5959437289012985
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |    loss |   val_loss |   val_accuracy |
# |----------------------------+----------+----------------+-------+-------------+---------+------------+----------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         | 1.91762 |   0.493062 |       0.520137 |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         | 1.27427 |   0.234808 |       0.255927 |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |         |            |                |
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:42:30 (running for 00:03:22.03)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.5959437289012985
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |    loss |   val_loss |   val_accuracy |
# |----------------------------+----------+----------------+-------+-------------+---------+------------+----------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         | 1.91762 |   0.493062 |       0.520137 |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         | 1.27427 |   0.234808 |       0.255927 |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |         |            |                |
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:42:35 (running for 00:03:27.07)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.5959437289012985
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |    loss |   val_loss |   val_accuracy |
# |----------------------------+----------+----------------+-------+-------------+---------+------------+----------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         | 1.91762 |   0.493062 |       0.520137 |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         | 1.27427 |   0.234808 |       0.255927 |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |         |            |                |
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:42:40 (running for 00:03:32.12)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.5959437289012985
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
# | Trial name                 | status   | loc            |    lr | optimizer   |    loss |   val_loss |   val_accuracy |
# |----------------------------+----------+----------------+-------+-------------+---------+------------+----------------|
# | train_resnet50_51ec7_00000 | RUNNING  | 172.19.2.2:372 | 0.1   | SGD         | 1.91762 |   0.493062 |       0.520137 |
# | train_resnet50_51ec7_00001 | RUNNING  | 172.19.2.2:373 | 0.001 | SGD         | 1.27427 |   0.234808 |       0.255927 |
# | train_resnet50_51ec7_00002 | PENDING  |                | 0.001 | SGD         |         |            |                |
# +----------------------------+----------+----------------+-------+-------------+---------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:42:45 (running for 00:03:37.16)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.5959437289012985
# Logical resource usage: 4.0/4 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 PENDING, 2 RUNNING)
# ...
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00002 | RUNNING    | 172.19.2.2:522 | 0.001 | SGD         | 1.03594  |   0.465259 |       0.60954  |
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:48:48 (running for 00:09:39.77)
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 4.000: -0.783038551517999 | Iter 2.000: -1.1685601514586939 | Iter 1.000: -1.38105472545827
# Logical resource usage: 2.0/4 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 RUNNING, 2 TERMINATED)
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00002 | RUNNING    | 172.19.2.2:522 | 0.001 | SGD         | 1.03594  |   0.465259 |       0.60954  |
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:48:53 (running for 00:09:44.80)
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 4.000: -0.783038551517999 | Iter 2.000: -1.1685601514586939 | Iter 1.000: -1.38105472545827
# Logical resource usage: 2.0/4 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 RUNNING, 2 TERMINATED)
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00002 | RUNNING    | 172.19.2.2:522 | 0.001 | SGD         | 1.03594  |   0.465259 |       0.60954  |
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:48:58 (running for 00:09:49.83)
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 4.000: -0.783038551517999 | Iter 2.000: -1.1685601514586939 | Iter 1.000: -1.38105472545827
# Logical resource usage: 2.0/4 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 RUNNING, 2 TERMINATED)
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00002 | RUNNING    | 172.19.2.2:522 | 0.001 | SGD         | 1.03594  |   0.465259 |       0.60954  |
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:49:03 (running for 00:09:54.86)
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 4.000: -0.783038551517999 | Iter 2.000: -1.1685601514586939 | Iter 1.000: -1.38105472545827
# Logical resource usage: 2.0/4 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 RUNNING, 2 TERMINATED)
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00002 | RUNNING    | 172.19.2.2:522 | 0.001 | SGD         | 1.03594  |   0.465259 |       0.60954  |
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:49:08 (running for 00:09:59.88)
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 4.000: -0.783038551517999 | Iter 2.000: -1.1685601514586939 | Iter 1.000: -1.38105472545827
# Logical resource usage: 2.0/4 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 RUNNING, 2 TERMINATED)
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00002 | RUNNING    | 172.19.2.2:522 | 0.001 | SGD         | 1.03594  |   0.465259 |       0.60954  |
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:49:13 (running for 00:10:04.91)
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 4.000: -0.783038551517999 | Iter 2.000: -1.1685601514586939 | Iter 1.000: -1.38105472545827
# Logical resource usage: 2.0/4 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 RUNNING, 2 TERMINATED)
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00002 | RUNNING    | 172.19.2.2:522 | 0.001 | SGD         | 1.03594  |   0.465259 |       0.60954  |
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:49:18 (running for 00:10:09.94)
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 4.000: -0.783038551517999 | Iter 2.000: -1.1685601514586939 | Iter 1.000: -1.38105472545827
# Logical resource usage: 2.0/4 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 RUNNING, 2 TERMINATED)
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00002 | RUNNING    | 172.19.2.2:522 | 0.001 | SGD         | 1.03594  |   0.465259 |       0.60954  |
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:49:23 (running for 00:10:14.97)
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 4.000: -0.783038551517999 | Iter 2.000: -1.1685601514586939 | Iter 1.000: -1.38105472545827
# Logical resource usage: 2.0/4 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 RUNNING, 2 TERMINATED)
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00002 | RUNNING    | 172.19.2.2:522 | 0.001 | SGD         | 1.03594  |   0.465259 |       0.60954  |
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:49:28 (running for 00:10:20.00)
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 4.000: -0.783038551517999 | Iter 2.000: -1.1685601514586939 | Iter 1.000: -1.38105472545827
# Logical resource usage: 2.0/4 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 RUNNING, 2 TERMINATED)
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00002 | RUNNING    | 172.19.2.2:522 | 0.001 | SGD         | 1.03594  |   0.465259 |       0.60954  |
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
#
#
# == Status ==
# Current time: 2024-10-30 13:49:33 (running for 00:10:25.03)
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 4.000: -0.783038551517999 | Iter 2.000: -1.1685601514586939 | Iter 1.000: -1.38105472545827
# Logical resource usage: 2.0/4 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (1 RUNNING, 2 TERMINATED)
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00002 | RUNNING    | 172.19.2.2:522 | 0.001 | SGD         | 1.03594  |   0.465259 |       0.60954  |
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# 2024-10-30 13:49:37,565	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_resnet50_2024-10-30_13-39-00' in 0.0059s.
# 2024-10-30 13:49:37,570	INFO tune.py:1041 -- Total run time: 637.21 seconds (628.87 seconds for the tuning loop).
# == Status ==
# Current time: 2024-10-30 13:49:37 (running for 00:10:28.88)
# Using AsyncHyperBand: num_stopped=3
# Bracket: Iter 4.000: -0.868869853788587 | Iter 2.000: -1.1685601514586939 | Iter 1.000: -1.38105472545827
# Logical resource usage: 2.0/4 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:T4)
# Result logdir: /tmp/ray/session_2024-10-30_13-38-54_743622_30/artifacts/2024-10-30_13-39-00/train_resnet50_2024-10-30_13-39-00/driver_artifacts
# Number of trials: 3/3 (3 TERMINATED)
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+
# | Trial name                 | status     | loc            |    lr | optimizer   |     loss |   val_loss |   val_accuracy |
# |----------------------------+------------+----------------+-------+-------------+----------+------------+----------------|
# | train_resnet50_51ec7_00000 | TERMINATED | 172.19.2.2:372 | 0.1   | SGD         | 1.56989  |   0.694207 |       0.52128  |
# | train_resnet50_51ec7_00001 | TERMINATED | 172.19.2.2:373 | 0.001 | SGD         | 0.783039 |   0.313103 |       0.715795 |
# | train_resnet50_51ec7_00002 | TERMINATED | 172.19.2.2:522 | 0.001 | SGD         | 0.954701 |   0.416708 |       0.61411  |
# +----------------------------+------------+----------------+-------+-------------+----------+------------+----------------+

# %%
analysis.get_best_config(metric="loss", mode="min")
# Out:
# {'lr': 0.001, 'optimizer': 'SGD'}
