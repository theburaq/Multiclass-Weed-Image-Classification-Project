# %% [markdown]
# In **this 5th notebook**, we'll implement a **pre-trained Inception-v3 model** to test on our dataset in place of ResNet-50 and ResNet-34 models. We'll also fine tune it and compare the results.

# %% [markdown]
# ##Loading the dataset

# %% [markdown]
# The images and datasets are provided on GitHub here: https://github.com/AlexOlsen/DeepWeeds/tree/master . And the labels are provided here: https://github.com/AlexOlsen/DeepWeeds/tree/master/labels .
#
#
#
# On the other hand, they can also be downloaded from TesnsorFlow dataset hub: https://www.tensorflow.org/datasets/catalog/deep_weeds .
#
#
#
# As we've run most of our models on Kaggle, so we've downloaded the datasets from GitHub and loaded all on the kaggle account.

# %%
pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->torchvision) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->torchvision) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow_datasets as tfds

import logging

from zipfile import ZipFile

import os

import sys

import shutil

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np



#from utils.events import download_google_drive_file

# %%
import os

os.listdir('/kaggle/input/')
# Out:
# ['train_subset1.csv',
#  'test_subset1.csv',
#  'val_subset0.csv',
#  'test_subset0.csv',
#  'train_subset0.csv',
#  'images',
#  'val_subset1.csv',
#  'labels.csv']

# %%
import pandas as pd

import os

from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split

from PIL import Image

import torch

from torchvision import transforms

import torchvision

from torchvision import models

import torch.nn as nn

import torch.optim as optim

from PIL import ImageFile

# %% [markdown]
# ##Applying Image Transformations

# %% [markdown]
# * We'll, now, apply **image transformations** to prepare the data for training and testing in our deep learning model. These transformations help to improve the model’s performance and generalization
#
#
#
# * Additionally, in both phases, we **normalize** the images using the mean and standard deviation values derived from the ImageNet dataset. This normalization step adjusts the pixel values to a common scale, which can expedite the training process and enhance model performance.

# %%
# Custom dataset class


class ImageDataset(Dataset):

    def __init__(self, csv_file, img_dir, transform=None):

        self.data_frame = pd.read_csv(csv_file)

        self.img_dir = img_dir

        self.transform = transform



    def __len__(self):

        return len(self.data_frame)



    def __getitem__(self, idx):

        img_name = os.path.join(self.img_dir, self.data_frame.iloc[idx, 0])

        image = Image.open(img_name)

        label = int(self.data_frame.iloc[idx, 1])



        if self.transform:

            image = self.transform(image)



        return image, label





# Load the CSV file

train_csv_file = '/kaggle/input/train_subset0.csv'  # Replace with your actual path

test_csv_file = '/kaggle/input/test_subset0.csv'  # Replace with your actual path

val_csv_file = '/kaggle/input/val_subset0.csv'  # Replace with your actual path

img_dir = '/kaggle/input/images'  # Replace with your images directory



# Image transformations (resize, normalization, etc.)

transform = transforms.Compose([

    transforms.Resize((299, 299)),  # Resizing to 299x299, you can adjust this

    transforms.ToTensor(),  #Converts the image into a PyTorch tensor and scales pixel values to [0, 1]

    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])     #Normalizes the image with a mean and standard deviation of [0.5, 0.5, 0.5] for the three RGB channels.

  ])





# Create the train and test datasets

train_dataset = ImageDataset(csv_file=train_csv_file, img_dir=img_dir, transform=transform)

test_dataset = ImageDataset(csv_file=test_csv_file, img_dir=img_dir, transform=transform)

val_dataset = ImageDataset(csv_file=val_csv_file, img_dir=img_dir, transform=transform)





# Create DataLoaders for batching

def create_dataloader(loader_type):

  if loader_type=='train':

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

    print(f"len train_loader {len(train_loader)}")

    return train_loader

  elif loader_type=='val':

    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

    return val_loader

  else:

    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    return test_loader

# %%
# Checking & printing the size of datasets



num_train_samples = len(train_dataset)

num_val_samples = len(val_dataset)

num_test_samples = len(test_dataset)

print(f"Number of training samples: {num_train_samples}")

print(f"Number of validation samples: {num_val_samples}")

print(f"Number of testing samples: {num_test_samples}")
# Out:
# Number of training samples: 10501
# Number of validation samples: 3501
# Number of testing samples: 3507

# %% [markdown]
# #The Model

# %%
import json   # For saving the history


# Load the pre-trained Inception v3 model:

model = models.inception_v3(pretrained=True)

num_ftrs = model.fc.in_features

model.fc = nn.Linear(num_ftrs, 9)  # Adjust for CIFAR-10 (8 classes)


# Loss function and optimizer:

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)


# Training History and Device Setup:
# Initialize history dictionary
history = {

        'train_loss': [],

        'train_accuracy': [],

        'val_loss': [],

        'val_accuracy': []

    }


# Add model name to the history dictionary
history['model_name'] = 'Pretrained Inception-v3'  # Change the name for each model in each notebook

best_val_accuracy = 0.0
best_model_path = "best_model_pretrained_inception_v3.pth"

# Device Setup
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)


# Dataloaders:

train_loader = create_dataloader(loader_type='train')
val_loader = create_dataloader(loader_type='val')


# Training Loop:

for epoch in range(100):              #You can adjust the number of epochs

          #training phase-

          model.train()

          running_loss = 0.0

          train_correct = 0

          train_total = 0

          #batch processing

          for i, (inputs, targets) in enumerate(train_loader):

              ImageFile.LOAD_TRUNCATED_IMAGES = True

              inputs, targets = inputs.to(device), targets.to(device)

              optimizer.zero_grad()

              outputs = model(inputs)

              _, predicted = outputs[0].max(1)    # Use output[0] to avoid error

              loss = criterion(outputs[0], targets)     # Only use the main output for loss calculation

              loss.backward()

              optimizer.step()

              #training metrics-

              running_loss += loss.item()

              train_total += targets.size(0)

              train_correct += predicted.eq(targets).sum().item()



              if i % 100 == 0:

                  print(f'Epoch [{epoch+1}/100], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')



          #training metrics-

          train_loss = running_loss / len(train_loader)

          train_accuracy = train_correct / train_total

          history['train_loss'].append(train_loss)

          history['train_accuracy'].append(train_accuracy)



          # Validation Loop:

          model.eval()

          val_loss = 0.0

          val_correct = 0

          val_total = 0

          with torch.no_grad():

            for inputs, targets in val_loader:

              inputs, targets = inputs.to(device), targets.to(device)

              outputs = model(inputs)

              _, predicted = outputs.max(1)

              loss = criterion(outputs, predicted)



              val_loss += loss.item()

              val_total += targets.size(0)

              val_correct += predicted.eq(targets).sum().item()



          # Calculate accuracy

          val_loss /= len(val_loader)

          val_accuracy = val_correct / val_total

          history['val_loss'].append(val_loss)

          history['val_accuracy'].append(val_accuracy)



          print(f'Epoch [{epoch+1}/100], Validation Accuracy: {val_accuracy:.4f}, Train Accuracy: {train_accuracy:.4f}')



          # Save Best Model / Model Checkpointing:

          if val_accuracy > best_val_accuracy:

            best_val_accuracy = val_accuracy
            history['best_val_accuracy'] = best_val_accuracy

            torch.save(model.state_dict(), best_model_path)

            print(f"New best model saved with Validation Accuracy: {val_accuracy:.4f}")


# Save the history as a JSON file:
history_file = 'history_pretrained_inception_v3.json'   # Change the filename for each model in each notebook
with open(history_file, 'w') as f:
    json.dump(history, f)

print(f"Training history saved to {history_file}")
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:01<00:00, 63.0MB/s]
# len train_loader 329
# Epoch [1/100], Step [1/329], Loss: 2.3984
# Epoch [1/100], Step [101/329], Loss: 0.9373
# Epoch [1/100], Step [201/329], Loss: 0.4476
# Epoch [1/100], Step [301/329], Loss: 0.2665
# Epoch [1/100], Validation Accuracy: 0.8769, Train Accuracy: 0.7721
# New best model saved with Validation Accuracy: 0.8769
# Epoch [2/100], Step [1/329], Loss: 0.2782
# Epoch [2/100], Step [101/329], Loss: 0.2195
# Epoch [2/100], Step [201/329], Loss: 0.2796
# Epoch [2/100], Step [301/329], Loss: 0.3711
# Epoch [2/100], Validation Accuracy: 0.9232, Train Accuracy: 0.9320
# New best model saved with Validation Accuracy: 0.9232
# Epoch [3/100], Step [1/329], Loss: 0.0995
# Epoch [3/100], Step [101/329], Loss: 0.2009
# Epoch [3/100], Step [201/329], Loss: 0.1706
# Epoch [3/100], Step [301/329], Loss: 0.1884
# Epoch [3/100], Validation Accuracy: 0.9300, Train Accuracy: 0.9668
# New best model saved with Validation Accuracy: 0.9300
# Epoch [4/100], Step [1/329], Loss: 0.0976
# Epoch [4/100], Step [101/329], Loss: 0.0327
# Epoch [4/100], Step [201/329], Loss: 0.0295
# Epoch [4/100], Step [301/329], Loss: 0.0234
# Epoch [4/100], Validation Accuracy: 0.9323, Train Accuracy: 0.9799
# New best model saved with Validation Accuracy: 0.9323
# Epoch [5/100], Step [1/329], Loss: 0.0440
# Epoch [5/100], Step [101/329], Loss: 0.0768
# Epoch [5/100], Step [201/329], Loss: 0.0185
# Epoch [5/100], Step [301/329], Loss: 0.0178
# Epoch [5/100], Validation Accuracy: 0.9237, Train Accuracy: 0.9805
# Epoch [6/100], Step [1/329], Loss: 0.1364
# Epoch [6/100], Step [101/329], Loss: 0.0115
# Epoch [6/100], Step [201/329], Loss: 0.1147
# Epoch [6/100], Step [301/329], Loss: 0.0278
# Epoch [6/100], Validation Accuracy: 0.9257, Train Accuracy: 0.9822
# Epoch [7/100], Step [1/329], Loss: 0.0132
# Epoch [7/100], Step [101/329], Loss: 0.0319
# Epoch [7/100], Step [201/329], Loss: 0.0076
# Epoch [7/100], Step [301/329], Loss: 0.2471
# Epoch [7/100], Validation Accuracy: 0.9252, Train Accuracy: 0.9872
# Epoch [8/100], Step [1/329], Loss: 0.5092
# Epoch [8/100], Step [101/329], Loss: 0.0152
# Epoch [8/100], Step [201/329], Loss: 0.0450
# Epoch [8/100], Step [301/329], Loss: 0.0079
# Epoch [8/100], Validation Accuracy: 0.9312, Train Accuracy: 0.9867
# Epoch [9/100], Step [1/329], Loss: 0.0074
# Epoch [9/100], Step [101/329], Loss: 0.0017
# Epoch [9/100], Step [201/329], Loss: 0.0033
# Epoch [9/100], Step [301/329], Loss: 0.0119
# Epoch [9/100], Validation Accuracy: 0.9403, Train Accuracy: 0.9912
# New best model saved with Validation Accuracy: 0.9403
# Epoch [10/100], Step [1/329], Loss: 0.0192
# Epoch [10/100], Step [101/329], Loss: 0.0386
# Epoch [10/100], Step [201/329], Loss: 0.1084
# Epoch [10/100], Step [301/329], Loss: 0.0030
# Epoch [10/100], Validation Accuracy: 0.9197, Train Accuracy: 0.9854
# Epoch [11/100], Step [1/329], Loss: 0.0061
# Epoch [11/100], Step [101/329], Loss: 0.2175
# Epoch [11/100], Step [201/329], Loss: 0.0156
# Epoch [11/100], Step [301/329], Loss: 0.0080
# Epoch [11/100], Validation Accuracy: 0.9283, Train Accuracy: 0.9918
# Epoch [12/100], Step [1/329], Loss: 0.0342
# Epoch [12/100], Step [101/329], Loss: 0.0268
# Epoch [12/100], Step [201/329], Loss: 0.0015
# Epoch [12/100], Step [301/329], Loss: 0.0285
# Epoch [12/100], Validation Accuracy: 0.9334, Train Accuracy: 0.9939
# Epoch [13/100], Step [1/329], Loss: 0.1457
# Epoch [13/100], Step [101/329], Loss: 0.0005
# Epoch [13/100], Step [201/329], Loss: 0.0400
# Epoch [13/100], Step [301/329], Loss: 0.0079
# Epoch [13/100], Validation Accuracy: 0.9057, Train Accuracy: 0.9886
# Epoch [14/100], Step [1/329], Loss: 0.0367
# Epoch [14/100], Step [101/329], Loss: 0.0223
# Epoch [14/100], Step [201/329], Loss: 0.0059
# Epoch [14/100], Step [301/329], Loss: 0.0086
# Epoch [14/100], Validation Accuracy: 0.9303, Train Accuracy: 0.9895
# Epoch [15/100], Step [1/329], Loss: 0.0340
# Epoch [15/100], Step [101/329], Loss: 0.0024
# Epoch [15/100], Step [201/329], Loss: 0.0743
# Epoch [15/100], Step [301/329], Loss: 0.0032
# Epoch [15/100], Validation Accuracy: 0.9343, Train Accuracy: 0.9904
# Epoch [16/100], Step [1/329], Loss: 0.0019
# Epoch [16/100], Step [101/329], Loss: 0.0384
# Epoch [16/100], Step [201/329], Loss: 0.0019
# Epoch [16/100], Step [301/329], Loss: 0.0056
# Epoch [16/100], Validation Accuracy: 0.9394, Train Accuracy: 0.9945
# Epoch [17/100], Step [1/329], Loss: 0.0011
# Epoch [17/100], Step [101/329], Loss: 0.0136
# Epoch [17/100], Step [201/329], Loss: 0.0884
# Epoch [17/100], Step [301/329], Loss: 0.0543
# Epoch [17/100], Validation Accuracy: 0.9272, Train Accuracy: 0.9944
# Epoch [18/100], Step [1/329], Loss: 0.0003
# Epoch [18/100], Step [101/329], Loss: 0.0120
# Epoch [18/100], Step [201/329], Loss: 0.0011
# Epoch [18/100], Step [301/329], Loss: 0.0372
# Epoch [18/100], Validation Accuracy: 0.9394, Train Accuracy: 0.9896
# Epoch [19/100], Step [1/329], Loss: 0.0034
# Epoch [19/100], Step [101/329], Loss: 0.0104
# Epoch [19/100], Step [201/329], Loss: 0.0010
# Epoch [19/100], Step [301/329], Loss: 0.0472
# Epoch [19/100], Validation Accuracy: 0.9212, Train Accuracy: 0.9964
# Epoch [20/100], Step [1/329], Loss: 0.0097
# Epoch [20/100], Step [101/329], Loss: 0.0831
# Epoch [20/100], Step [201/329], Loss: 0.0051
# Epoch [20/100], Step [301/329], Loss: 0.0054
# Epoch [20/100], Validation Accuracy: 0.9317, Train Accuracy: 0.9892
# Epoch [21/100], Step [1/329], Loss: 0.0248
# Epoch [21/100], Step [101/329], Loss: 0.0018
# Epoch [21/100], Step [201/329], Loss: 0.0005
# Epoch [21/100], Step [301/329], Loss: 0.1111
# Epoch [21/100], Validation Accuracy: 0.9320, Train Accuracy: 0.9921
# Epoch [22/100], Step [1/329], Loss: 0.0071
# Epoch [22/100], Step [101/329], Loss: 0.0413
# Epoch [22/100], Step [201/329], Loss: 0.0049
# Epoch [22/100], Step [301/329], Loss: 0.0009
# Epoch [22/100], Validation Accuracy: 0.9383, Train Accuracy: 0.9885
# Epoch [23/100], Step [1/329], Loss: 0.0073
# Epoch [23/100], Step [101/329], Loss: 0.0006
# Epoch [23/100], Step [201/329], Loss: 0.0126
# Epoch [23/100], Step [301/329], Loss: 0.0175
# Epoch [23/100], Validation Accuracy: 0.9403, Train Accuracy: 0.9947
# Epoch [24/100], Step [1/329], Loss: 0.0046
# Epoch [24/100], Step [101/329], Loss: 0.0029
# Epoch [24/100], Step [201/329], Loss: 0.0100
# Epoch [24/100], Step [301/329], Loss: 0.0009
# Epoch [24/100], Validation Accuracy: 0.9377, Train Accuracy: 0.9966
# Epoch [25/100], Step [1/329], Loss: 0.0015
# Epoch [25/100], Step [101/329], Loss: 0.0337
# Epoch [25/100], Step [201/329], Loss: 0.0011
# Epoch [25/100], Step [301/329], Loss: 0.0479
# Epoch [25/100], Validation Accuracy: 0.9400, Train Accuracy: 0.9940
# Epoch [26/100], Step [1/329], Loss: 0.0030
# Epoch [26/100], Step [101/329], Loss: 0.0180
# Epoch [26/100], Step [201/329], Loss: 0.0034
# Epoch [26/100], Step [301/329], Loss: 0.0023
# Epoch [26/100], Validation Accuracy: 0.9409, Train Accuracy: 0.9900
# New best model saved with Validation Accuracy: 0.9409
# Epoch [27/100], Step [1/329], Loss: 0.0032
# Epoch [27/100], Step [101/329], Loss: 0.0111
# Epoch [27/100], Step [201/329], Loss: 0.0529
# Epoch [27/100], Step [301/329], Loss: 0.0024
# Epoch [27/100], Validation Accuracy: 0.9480, Train Accuracy: 0.9969
# New best model saved with Validation Accuracy: 0.9480
# Epoch [28/100], Step [1/329], Loss: 0.0047
# Epoch [28/100], Step [101/329], Loss: 0.0040
# Epoch [28/100], Step [201/329], Loss: 0.0070
# Epoch [28/100], Step [301/329], Loss: 0.0073
# Epoch [28/100], Validation Accuracy: 0.9397, Train Accuracy: 0.9880
# Epoch [29/100], Step [1/329], Loss: 0.0022
# Epoch [29/100], Step [101/329], Loss: 0.0023
# Epoch [29/100], Step [201/329], Loss: 0.0076
# Epoch [29/100], Step [301/329], Loss: 0.0074
# Epoch [29/100], Validation Accuracy: 0.9343, Train Accuracy: 0.9887
# Epoch [30/100], Step [1/329], Loss: 0.0012
# Epoch [30/100], Step [101/329], Loss: 0.0715
# Epoch [30/100], Step [201/329], Loss: 0.0331
# Epoch [30/100], Step [301/329], Loss: 0.0020
# Epoch [30/100], Validation Accuracy: 0.9417, Train Accuracy: 0.9965
# Epoch [31/100], Step [1/329], Loss: 0.0006
# Epoch [31/100], Step [101/329], Loss: 0.0009
# Epoch [31/100], Step [201/329], Loss: 0.0013
# Epoch [31/100], Step [301/329], Loss: 0.1239
# Epoch [31/100], Validation Accuracy: 0.9366, Train Accuracy: 0.9948
# Epoch [32/100], Step [1/329], Loss: 0.0021
# Epoch [32/100], Step [101/329], Loss: 0.0004
# Epoch [32/100], Step [201/329], Loss: 0.0032
# Epoch [32/100], Step [301/329], Loss: 0.0005
# Epoch [32/100], Validation Accuracy: 0.9389, Train Accuracy: 0.9976
# Epoch [33/100], Step [1/329], Loss: 0.0091
# Epoch [33/100], Step [101/329], Loss: 0.0068
# Epoch [33/100], Step [201/329], Loss: 0.1150
# Epoch [33/100], Step [301/329], Loss: 0.1136
# Epoch [33/100], Validation Accuracy: 0.9434, Train Accuracy: 0.9864
# Epoch [34/100], Step [1/329], Loss: 0.0031
# Epoch [34/100], Step [101/329], Loss: 0.0682
# Epoch [34/100], Step [201/329], Loss: 0.0664
# Epoch [34/100], Step [301/329], Loss: 0.0144
# Epoch [34/100], Validation Accuracy: 0.9492, Train Accuracy: 0.9929
# New best model saved with Validation Accuracy: 0.9492
# Epoch [35/100], Step [1/329], Loss: 0.0023
# Epoch [35/100], Step [101/329], Loss: 0.0003
# Epoch [35/100], Step [201/329], Loss: 0.0028
# Epoch [35/100], Step [301/329], Loss: 0.0001
# Epoch [35/100], Validation Accuracy: 0.9486, Train Accuracy: 0.9981
# Epoch [36/100], Step [1/329], Loss: 0.0009
# Epoch [36/100], Step [101/329], Loss: 0.0044
# Epoch [36/100], Step [201/329], Loss: 0.0011
# Epoch [36/100], Step [301/329], Loss: 0.0053
# Epoch [36/100], Validation Accuracy: 0.9469, Train Accuracy: 0.9962
# Epoch [37/100], Step [1/329], Loss: 0.0003
# Epoch [37/100], Step [101/329], Loss: 0.0007
# Epoch [37/100], Step [201/329], Loss: 0.0004
# Epoch [37/100], Step [301/329], Loss: 0.0024
# Epoch [37/100], Validation Accuracy: 0.9492, Train Accuracy: 0.9982
# Epoch [38/100], Step [1/329], Loss: 0.0257
# Epoch [38/100], Step [101/329], Loss: 0.0001
# Epoch [38/100], Step [201/329], Loss: 0.0069
# Epoch [38/100], Step [301/329], Loss: 0.0389
# Epoch [38/100], Validation Accuracy: 0.9383, Train Accuracy: 0.9961
# Epoch [39/100], Step [1/329], Loss: 0.0077
# Epoch [39/100], Step [101/329], Loss: 0.0220
# Epoch [39/100], Step [201/329], Loss: 0.0071
# Epoch [39/100], Step [301/329], Loss: 0.0005
# Epoch [39/100], Validation Accuracy: 0.9417, Train Accuracy: 0.9909
# Epoch [40/100], Step [1/329], Loss: 0.0011
# Epoch [40/100], Step [101/329], Loss: 0.0037
# Epoch [40/100], Step [201/329], Loss: 0.0156
# Epoch [40/100], Step [301/329], Loss: 0.0007
# Epoch [40/100], Validation Accuracy: 0.9372, Train Accuracy: 0.9968
# Epoch [41/100], Step [1/329], Loss: 0.0088
# Epoch [41/100], Step [101/329], Loss: 0.0036
# Epoch [41/100], Step [201/329], Loss: 0.0002
# Epoch [41/100], Step [301/329], Loss: 0.0007
# Epoch [41/100], Validation Accuracy: 0.9294, Train Accuracy: 0.9962
# Epoch [42/100], Step [1/329], Loss: 0.0003
# Epoch [42/100], Step [101/329], Loss: 0.0037
# Epoch [42/100], Step [201/329], Loss: 0.0302
# Epoch [42/100], Step [301/329], Loss: 0.0008
# Epoch [42/100], Validation Accuracy: 0.9449, Train Accuracy: 0.9944
# Epoch [43/100], Step [1/329], Loss: 0.0002
# Epoch [43/100], Step [101/329], Loss: 0.0008
# Epoch [43/100], Step [201/329], Loss: 0.0009
# Epoch [43/100], Step [301/329], Loss: 0.0008
# Epoch [43/100], Validation Accuracy: 0.9437, Train Accuracy: 0.9981
# Epoch [44/100], Step [1/329], Loss: 0.0021
# Epoch [44/100], Step [101/329], Loss: 0.0004
# Epoch [44/100], Step [201/329], Loss: 0.0005
# Epoch [44/100], Step [301/329], Loss: 0.0006
# Epoch [44/100], Validation Accuracy: 0.9514, Train Accuracy: 0.9989
# New best model saved with Validation Accuracy: 0.9514
# Epoch [45/100], Step [1/329], Loss: 0.0027
# Epoch [45/100], Step [101/329], Loss: 0.0013
# Epoch [45/100], Step [201/329], Loss: 0.0002
# Epoch [45/100], Step [301/329], Loss: 0.0003
# Epoch [45/100], Validation Accuracy: 0.9300, Train Accuracy: 0.9979
# Epoch [46/100], Step [1/329], Loss: 0.0258
# Epoch [46/100], Step [101/329], Loss: 0.0007
# Epoch [46/100], Step [201/329], Loss: 0.0144
# Epoch [46/100], Step [301/329], Loss: 0.0009
# Epoch [46/100], Validation Accuracy: 0.9517, Train Accuracy: 0.9883
# New best model saved with Validation Accuracy: 0.9517
# Epoch [47/100], Step [1/329], Loss: 0.0009
# Epoch [47/100], Step [101/329], Loss: 0.0017
# Epoch [47/100], Step [201/329], Loss: 0.0002
# Epoch [47/100], Step [301/329], Loss: 0.0272
# Epoch [47/100], Validation Accuracy: 0.9414, Train Accuracy: 0.9952
# Epoch [48/100], Step [1/329], Loss: 0.0062
# Epoch [48/100], Step [101/329], Loss: 0.0012
# Epoch [48/100], Step [201/329], Loss: 0.0003
# Epoch [48/100], Step [301/329], Loss: 0.0078
# Epoch [48/100], Validation Accuracy: 0.9480, Train Accuracy: 0.9989
# Epoch [49/100], Step [1/329], Loss: 0.0005
# Epoch [49/100], Step [101/329], Loss: 0.0137
# Epoch [49/100], Step [201/329], Loss: 0.0008
# Epoch [49/100], Step [301/329], Loss: 0.0009
# Epoch [49/100], Validation Accuracy: 0.9520, Train Accuracy: 0.9983
# New best model saved with Validation Accuracy: 0.9520
# Epoch [50/100], Step [1/329], Loss: 0.0001
# Epoch [50/100], Step [101/329], Loss: 0.0259
# Epoch [50/100], Step [201/329], Loss: 0.0001
# Epoch [50/100], Step [301/329], Loss: 0.0108
# Epoch [50/100], Validation Accuracy: 0.9497, Train Accuracy: 0.9970
# Epoch [51/100], Step [1/329], Loss: 0.0065
# Epoch [51/100], Step [101/329], Loss: 0.0015
# Epoch [51/100], Step [201/329], Loss: 0.0098
# Epoch [51/100], Step [301/329], Loss: 0.0227
# Epoch [51/100], Validation Accuracy: 0.9289, Train Accuracy: 0.9944
# Epoch [52/100], Step [1/329], Loss: 0.0003
# Epoch [52/100], Step [101/329], Loss: 0.1085
# Epoch [52/100], Step [201/329], Loss: 0.0319
# Epoch [52/100], Step [301/329], Loss: 0.0027
# Epoch [52/100], Validation Accuracy: 0.9406, Train Accuracy: 0.9961
# Epoch [53/100], Step [1/329], Loss: 0.0009
# Epoch [53/100], Step [101/329], Loss: 0.0309
# Epoch [53/100], Step [201/329], Loss: 0.0027
# Epoch [53/100], Step [301/329], Loss: 0.0009
# Epoch [53/100], Validation Accuracy: 0.9374, Train Accuracy: 0.9941
# Epoch [54/100], Step [1/329], Loss: 0.0004
# Epoch [54/100], Step [101/329], Loss: 0.0001
# Epoch [54/100], Step [201/329], Loss: 0.0335
# Epoch [54/100], Step [301/329], Loss: 0.0055
# Epoch [54/100], Validation Accuracy: 0.9429, Train Accuracy: 0.9955
# Epoch [55/100], Step [1/329], Loss: 0.0007
# Epoch [55/100], Step [101/329], Loss: 0.0004
# Epoch [55/100], Step [201/329], Loss: 0.1285
# Epoch [55/100], Step [301/329], Loss: 0.0016
# Epoch [55/100], Validation Accuracy: 0.9446, Train Accuracy: 0.9962
# Epoch [56/100], Step [1/329], Loss: 0.0020
# Epoch [56/100], Step [101/329], Loss: 0.0004
# Epoch [56/100], Step [201/329], Loss: 0.0013
# Epoch [56/100], Step [301/329], Loss: 0.0001
# Epoch [56/100], Validation Accuracy: 0.9506, Train Accuracy: 0.9973
# Epoch [57/100], Step [1/329], Loss: 0.0010
# Epoch [57/100], Step [101/329], Loss: 0.0004
# Epoch [57/100], Step [201/329], Loss: 0.0004
# Epoch [57/100], Step [301/329], Loss: 0.0137
# Epoch [57/100], Validation Accuracy: 0.9454, Train Accuracy: 0.9984
# Epoch [58/100], Step [1/329], Loss: 0.0002
# Epoch [58/100], Step [101/329], Loss: 0.0001
# Epoch [58/100], Step [201/329], Loss: 0.0002
# Epoch [58/100], Step [301/329], Loss: 0.0021
# Epoch [58/100], Validation Accuracy: 0.9366, Train Accuracy: 0.9952
# Epoch [59/100], Step [1/329], Loss: 0.0012
# Epoch [59/100], Step [101/329], Loss: 0.0001
# Epoch [59/100], Step [201/329], Loss: 0.0007
# Epoch [59/100], Step [301/329], Loss: 0.0085
# Epoch [59/100], Validation Accuracy: 0.9457, Train Accuracy: 0.9960
# Epoch [60/100], Step [1/329], Loss: 0.0008
# Epoch [60/100], Step [101/329], Loss: 0.0238
# Epoch [60/100], Step [201/329], Loss: 0.0020
# Epoch [60/100], Step [301/329], Loss: 0.0039
# Epoch [60/100], Validation Accuracy: 0.9406, Train Accuracy: 0.9963
# Epoch [61/100], Step [1/329], Loss: 0.0005
# Epoch [61/100], Step [101/329], Loss: 0.0014
# Epoch [61/100], Step [201/329], Loss: 0.1006
# Epoch [61/100], Step [301/329], Loss: 0.0002
# Epoch [61/100], Validation Accuracy: 0.9274, Train Accuracy: 0.9955
# Epoch [62/100], Step [1/329], Loss: 0.0005
# Epoch [62/100], Step [101/329], Loss: 0.0107
# Epoch [62/100], Step [201/329], Loss: 0.0040
# Epoch [62/100], Step [301/329], Loss: 0.0144
# Epoch [62/100], Validation Accuracy: 0.9312, Train Accuracy: 0.9919
# Epoch [63/100], Step [1/329], Loss: 0.0040
# Epoch [63/100], Step [101/329], Loss: 0.0028
# Epoch [63/100], Step [201/329], Loss: 0.0037
# Epoch [63/100], Step [301/329], Loss: 0.0003
# Epoch [63/100], Validation Accuracy: 0.9477, Train Accuracy: 0.9985
# Epoch [64/100], Step [1/329], Loss: 0.0000
# Epoch [64/100], Step [101/329], Loss: 0.0004
# Epoch [64/100], Step [201/329], Loss: 0.0001
# Epoch [64/100], Step [301/329], Loss: 0.0008
# Epoch [64/100], Validation Accuracy: 0.9526, Train Accuracy: 0.9988
# New best model saved with Validation Accuracy: 0.9526
# Epoch [65/100], Step [1/329], Loss: 0.0016
# Epoch [65/100], Step [101/329], Loss: 0.0001
# Epoch [65/100], Step [201/329], Loss: 0.0002
# Epoch [65/100], Step [301/329], Loss: 0.0000
# Epoch [65/100], Validation Accuracy: 0.9474, Train Accuracy: 0.9999
# Epoch [66/100], Step [1/329], Loss: 0.0006
# Epoch [66/100], Step [101/329], Loss: 0.0001
# Epoch [66/100], Step [201/329], Loss: 0.0003
# Epoch [66/100], Step [301/329], Loss: 0.0107
# Epoch [66/100], Validation Accuracy: 0.9374, Train Accuracy: 0.9990
# Epoch [67/100], Step [1/329], Loss: 0.0004
# Epoch [67/100], Step [101/329], Loss: 0.0002
# Epoch [67/100], Step [201/329], Loss: 0.0026
# Epoch [67/100], Step [301/329], Loss: 0.0022
# Epoch [67/100], Validation Accuracy: 0.9294, Train Accuracy: 0.9934
# Epoch [68/100], Step [1/329], Loss: 0.0012
# Epoch [68/100], Step [101/329], Loss: 0.0020
# Epoch [68/100], Step [201/329], Loss: 0.0011
# Epoch [68/100], Step [301/329], Loss: 0.0008
# Epoch [68/100], Validation Accuracy: 0.9403, Train Accuracy: 0.9959
# Epoch [69/100], Step [1/329], Loss: 0.0017
# Epoch [69/100], Step [101/329], Loss: 0.0001
# Epoch [69/100], Step [201/329], Loss: 0.0001
# Epoch [69/100], Step [301/329], Loss: 0.0002
# Epoch [69/100], Validation Accuracy: 0.9237, Train Accuracy: 0.9984
# Epoch [70/100], Step [1/329], Loss: 0.0039
# Epoch [70/100], Step [101/329], Loss: 0.0035
# Epoch [70/100], Step [201/329], Loss: 0.0001
# Epoch [70/100], Step [301/329], Loss: 0.0011
# Epoch [70/100], Validation Accuracy: 0.9434, Train Accuracy: 0.9984
# Epoch [71/100], Step [1/329], Loss: 0.0003
# Epoch [71/100], Step [101/329], Loss: 0.0100
# Epoch [71/100], Step [201/329], Loss: 0.1976
# Epoch [71/100], Step [301/329], Loss: 0.0088
# Epoch [71/100], Validation Accuracy: 0.9394, Train Accuracy: 0.9923
# Epoch [72/100], Step [1/329], Loss: 0.0113
# Epoch [72/100], Step [101/329], Loss: 0.1492
# Epoch [72/100], Step [201/329], Loss: 0.0316
# Epoch [72/100], Step [301/329], Loss: 0.0005
# Epoch [72/100], Validation Accuracy: 0.9432, Train Accuracy: 0.9946
# Epoch [73/100], Step [1/329], Loss: 0.0003
# Epoch [73/100], Step [101/329], Loss: 0.0037
# Epoch [73/100], Step [201/329], Loss: 0.0035
# Epoch [73/100], Step [301/329], Loss: 0.0122
# Epoch [73/100], Validation Accuracy: 0.9414, Train Accuracy: 0.9943
# Epoch [74/100], Step [1/329], Loss: 0.0012
# Epoch [74/100], Step [101/329], Loss: 0.0027
# Epoch [74/100], Step [201/329], Loss: 0.0050
# Epoch [74/100], Step [301/329], Loss: 0.0003
# Epoch [74/100], Validation Accuracy: 0.9463, Train Accuracy: 0.9985
# Epoch [75/100], Step [1/329], Loss: 0.0003
# Epoch [75/100], Step [101/329], Loss: 0.0113
# Epoch [75/100], Step [201/329], Loss: 0.0000
# Epoch [75/100], Step [301/329], Loss: 0.0005
# Epoch [75/100], Validation Accuracy: 0.9443, Train Accuracy: 0.9979
# Epoch [76/100], Step [1/329], Loss: 0.0002
# Epoch [76/100], Step [101/329], Loss: 0.0005
# Epoch [76/100], Step [201/329], Loss: 0.0018
# Epoch [76/100], Step [301/329], Loss: 0.0185
# Epoch [76/100], Validation Accuracy: 0.9432, Train Accuracy: 0.9974
# Epoch [77/100], Step [1/329], Loss: 0.0009
# Epoch [77/100], Step [101/329], Loss: 0.0002
# Epoch [77/100], Step [201/329], Loss: 0.0157
# Epoch [77/100], Step [301/329], Loss: 0.0001
# Epoch [77/100], Validation Accuracy: 0.9363, Train Accuracy: 0.9983
# Epoch [78/100], Step [1/329], Loss: 0.0033
# Epoch [78/100], Step [101/329], Loss: 0.0384
# Epoch [78/100], Step [201/329], Loss: 0.0005
# Epoch [78/100], Step [301/329], Loss: 0.0002
# Epoch [78/100], Validation Accuracy: 0.9394, Train Accuracy: 0.9984
# Epoch [79/100], Step [1/329], Loss: 0.0016
# Epoch [79/100], Step [101/329], Loss: 0.0001
# Epoch [79/100], Step [201/329], Loss: 0.0015
# Epoch [79/100], Step [301/329], Loss: 0.0000
# Epoch [79/100], Validation Accuracy: 0.9360, Train Accuracy: 0.9986
# Epoch [80/100], Step [1/329], Loss: 0.0006
# Epoch [80/100], Step [101/329], Loss: 0.0690
# Epoch [80/100], Step [201/329], Loss: 0.0190
# Epoch [80/100], Step [301/329], Loss: 0.0008
# Epoch [80/100], Validation Accuracy: 0.9434, Train Accuracy: 0.9894
# Epoch [81/100], Step [1/329], Loss: 0.1240
# Epoch [81/100], Step [101/329], Loss: 0.0001
# Epoch [81/100], Step [201/329], Loss: 0.0004
# Epoch [81/100], Step [301/329], Loss: 0.0004
# Epoch [81/100], Validation Accuracy: 0.9529, Train Accuracy: 0.9983
# New best model saved with Validation Accuracy: 0.9529
# Epoch [82/100], Step [1/329], Loss: 0.0002
# Epoch [82/100], Step [101/329], Loss: 0.0001
# Epoch [82/100], Step [201/329], Loss: 0.0032
# Epoch [82/100], Step [301/329], Loss: 0.0001
# Epoch [82/100], Validation Accuracy: 0.9506, Train Accuracy: 0.9997
# Epoch [83/100], Step [1/329], Loss: 0.0011
# Epoch [83/100], Step [101/329], Loss: 0.0019
# Epoch [83/100], Step [201/329], Loss: 0.0002
# Epoch [83/100], Step [301/329], Loss: 0.1602
# Epoch [83/100], Validation Accuracy: 0.9343, Train Accuracy: 0.9968
# Epoch [84/100], Step [1/329], Loss: 0.0001
# Epoch [84/100], Step [101/329], Loss: 0.0002
# Epoch [84/100], Step [201/329], Loss: 0.0004
# Epoch [84/100], Step [301/329], Loss: 0.0003
# Epoch [84/100], Validation Accuracy: 0.9503, Train Accuracy: 0.9989
# Epoch [85/100], Step [1/329], Loss: 0.0000
# Epoch [85/100], Step [101/329], Loss: 0.0001
# Epoch [85/100], Step [201/329], Loss: 0.0001
# Epoch [85/100], Step [301/329], Loss: 0.0039
# Epoch [85/100], Validation Accuracy: 0.9526, Train Accuracy: 1.0000
# Epoch [86/100], Step [1/329], Loss: 0.0001
# Epoch [86/100], Step [101/329], Loss: 0.0000
# Epoch [86/100], Step [201/329], Loss: 0.0001
# Epoch [86/100], Step [301/329], Loss: 0.0000
# Epoch [86/100], Validation Accuracy: 0.9363, Train Accuracy: 0.9987
# Epoch [87/100], Step [1/329], Loss: 0.0762
# Epoch [87/100], Step [101/329], Loss: 0.0000
# Epoch [87/100], Step [201/329], Loss: 0.0003
# Epoch [87/100], Step [301/329], Loss: 0.0003
# Epoch [87/100], Validation Accuracy: 0.9454, Train Accuracy: 0.9968
# Epoch [88/100], Step [1/329], Loss: 0.0014
# Epoch [88/100], Step [101/329], Loss: 0.0026
# Epoch [88/100], Step [201/329], Loss: 0.0000
# Epoch [88/100], Step [301/329], Loss: 0.0305
# Epoch [88/100], Validation Accuracy: 0.9423, Train Accuracy: 0.9966
# Epoch [89/100], Step [1/329], Loss: 0.0109
# Epoch [89/100], Step [101/329], Loss: 0.0009
# Epoch [89/100], Step [201/329], Loss: 0.0003
# Epoch [89/100], Step [301/329], Loss: 0.0016
# Epoch [89/100], Validation Accuracy: 0.9334, Train Accuracy: 0.9977
# Epoch [90/100], Step [1/329], Loss: 0.0004
# Epoch [90/100], Step [101/329], Loss: 0.0002
# Epoch [90/100], Step [201/329], Loss: 0.0003
# Epoch [90/100], Step [301/329], Loss: 0.0021
# Epoch [90/100], Validation Accuracy: 0.9343, Train Accuracy: 0.9968
# Epoch [91/100], Step [1/329], Loss: 0.0003
# Epoch [91/100], Step [101/329], Loss: 0.0000
# Epoch [91/100], Step [201/329], Loss: 0.0015
# Epoch [91/100], Step [301/329], Loss: 0.0083
# Epoch [91/100], Validation Accuracy: 0.9432, Train Accuracy: 0.9959
# Epoch [92/100], Step [1/329], Loss: 0.0002
# Epoch [92/100], Step [101/329], Loss: 0.0004
# Epoch [92/100], Step [201/329], Loss: 0.0033
# Epoch [92/100], Step [301/329], Loss: 0.0000
# Epoch [92/100], Validation Accuracy: 0.9417, Train Accuracy: 0.9975
# Epoch [93/100], Step [1/329], Loss: 0.0010
# Epoch [93/100], Step [101/329], Loss: 0.0012
# Epoch [93/100], Step [201/329], Loss: 0.0260
# Epoch [93/100], Step [301/329], Loss: 0.0334
# Epoch [93/100], Validation Accuracy: 0.9403, Train Accuracy: 0.9963
# Epoch [94/100], Step [1/329], Loss: 0.0036
# Epoch [94/100], Step [101/329], Loss: 0.0015
# Epoch [94/100], Step [201/329], Loss: 0.0003
# Epoch [94/100], Step [301/329], Loss: 0.0000
# Epoch [94/100], Validation Accuracy: 0.9463, Train Accuracy: 0.9992
# Epoch [95/100], Step [1/329], Loss: 0.0005
# Epoch [95/100], Step [101/329], Loss: 0.0002
# Epoch [95/100], Step [201/329], Loss: 0.0202
# Epoch [95/100], Step [301/329], Loss: 0.0002
# Epoch [95/100], Validation Accuracy: 0.9326, Train Accuracy: 0.9963
# Epoch [96/100], Step [1/329], Loss: 0.0012
# Epoch [96/100], Step [101/329], Loss: 0.0028
# Epoch [96/100], Step [201/329], Loss: 0.0047
# Epoch [96/100], Step [301/329], Loss: 0.0004
# Epoch [96/100], Validation Accuracy: 0.9389, Train Accuracy: 0.9937
# Epoch [97/100], Step [1/329], Loss: 0.0010
# Epoch [97/100], Step [101/329], Loss: 0.0001
# Epoch [97/100], Step [201/329], Loss: 0.0023
# Epoch [97/100], Step [301/329], Loss: 0.0001
# Epoch [97/100], Validation Accuracy: 0.9489, Train Accuracy: 0.9985
# Epoch [98/100], Step [1/329], Loss: 0.0002
# Epoch [98/100], Step [101/329], Loss: 0.0002
# Epoch [98/100], Step [201/329], Loss: 0.0001
# Epoch [98/100], Step [301/329], Loss: 0.0001
# Epoch [98/100], Validation Accuracy: 0.9454, Train Accuracy: 0.9995
# Epoch [99/100], Step [1/329], Loss: 0.0080
# Epoch [99/100], Step [101/329], Loss: 0.0013
# Epoch [99/100], Step [201/329], Loss: 0.0041
# Epoch [99/100], Step [301/329], Loss: 0.0195
# Epoch [99/100], Validation Accuracy: 0.9429, Train Accuracy: 0.9973
# Epoch [100/100], Step [1/329], Loss: 0.0032
# Epoch [100/100], Step [101/329], Loss: 0.0008
# Epoch [100/100], Step [201/329], Loss: 0.0335
# Epoch [100/100], Step [301/329], Loss: 0.0002
# Epoch [100/100], Validation Accuracy: 0.9500, Train Accuracy: 0.9977
# Training history saved to history_pretrained_inception_v3.json

# %%
history
# Out:
# {'train_loss': [0.6961309313774109,
#   0.21456220982692525,
#   0.10930844210654407,
#   0.06990039518306819,
#   0.061162609002612375,
#   0.059886772828856,
#   0.042626327422085164,
#   0.042495160037722426,
#   0.030043110215865178,
#   0.04683110099193841,
#   0.030636629777766572,
#   0.019984950890727795,
#   0.03472258870371003,
#   0.034392526300021056,
#   0.02958529590969441,
#   0.01815894269870982,
#   0.02081808486597232,
#   0.030888285279209587,
#   0.014989249775537197,
#   0.03561188158257879,
#   0.025222942473081655,
#   0.03278669274380603,
#   0.01677978050562066,
#   0.01255218824488907,
#   0.017337879191262798,
#   0.03208941059476501,
#   0.016663205904987325,
#   0.03731000271189171,
#   0.03327732527148018,
#   0.011673166667639156,
#   0.019260628383778643,
#   0.014433384339019407,
#   0.046727991333312006,
#   0.02467975230681594,
#   0.00936599699584845,
#   0.012079408053104557,
#   0.006742986086310145,
#   0.015886552447412803,
#   0.031824993914666255,
#   0.01103018429134407,
#   0.011590456288026775,
#   0.01819012465724091,
#   0.008090194231719253,
#   0.004189298178938339,
#   0.009744453460843721,
#   0.038506818082041885,
#   0.01434633605966205,
#   0.006147665718375206,
#   0.005153413252390784,
#   0.013073094345743861,
#   0.02149095828043393,
#   0.012595004265405921,
#   0.016766454576423367,
#   0.013380486528196045,
#   0.012190257401619069,
#   0.00935595234452227,
#   0.005052901447364073,
#   0.016435141616546384,
#   0.013353697414920679,
#   0.011417002483957701,
#   0.017794344074416664,
#   0.028240840138632543,
#   0.005637862894047021,
#   0.0033725882882667574,
#   0.0013540688009676563,
#   0.00398076720578869,
#   0.021400893004419174,
#   0.01240169246639723,
#   0.0053666750028714665,
#   0.008241808939170219,
#   0.019148843483854296,
#   0.018415325136173562,
#   0.018804690004907153,
#   0.0053011605922893895,
#   0.006565631608091529,
#   0.008035368063271885,
#   0.007597148154208627,
#   0.00597244354996242,
#   0.005851162119333573,
#   0.03273222317432066,
#   0.007277792297097738,
#   0.001955097976666106,
#   0.00954112095803097,
#   0.005345213654472458,
#   0.000740070443880043,
#   0.00500046616645558,
#   0.008798397305780309,
#   0.009843958098851868,
#   0.009167627571995468,
#   0.011806961198377493,
#   0.014736970632089917,
#   0.008627946376959546,
#   0.011808246299262802,
#   0.003921430884989013,
#   0.02020006493894526,
#   0.022518391242628267,
#   0.00575024075253533,
#   0.005482126338036235,
#   0.008218188108104135,
#   0.007297409950916382],
#  'train_accuracy': [0.7721169412436911,
#   0.9320064755737549,
#   0.966765069993334,
#   0.9799066755547091,
#   0.9804780497095514,
#   0.9821921721740786,
#   0.9872393105418532,
#   0.9866679363870108,
#   0.9912389296257499,
#   0.9854299590515189,
#   0.9918103037805923,
#   0.9939053423483478,
#   0.9885725169031521,
#   0.9895248071612227,
#   0.9903818683934863,
#   0.9944767165031901,
#   0.9943814874773831,
#   0.9896200361870298,
#   0.9963812970193315,
#   0.9892391200838015,
#   0.9920959908580135,
#   0.988477287877345,
#   0.9946671745548044,
#   0.9965717550709456,
#   0.9940005713741549,
#   0.9900009522902581,
#   0.9968574421483668,
#   0.9880011427483096,
#   0.9886677459289591,
#   0.9964765260451386,
#   0.9947624035806114,
#   0.9976192743548233,
#   0.9863822493095895,
#   0.99285782306447,
#   0.9980954194838587,
#   0.9961908389677173,
#   0.9981906485096658,
#   0.9960956099419103,
#   0.9908580135225217,
#   0.9967622131225597,
#   0.9961908389677173,
#   0.9943814874773831,
#   0.9980954194838587,
#   0.9988572516903153,
#   0.9979049614322445,
#   0.9882868298257309,
#   0.9952385487096467,
#   0.9988572516903153,
#   0.9982858775354728,
#   0.9969526711741739,
#   0.9943814874773831,
#   0.9960956099419103,
#   0.9940958003999619,
#   0.995524235787068,
#   0.9961908389677173,
#   0.9973335872774022,
#   0.9983811065612799,
#   0.9952385487096467,
#   0.9960003809161032,
#   0.9962860679935244,
#   0.995524235787068,
#   0.9919055328063994,
#   0.9984763355870869,
#   0.9987620226645081,
#   0.999904770974193,
#   0.9989524807161223,
#   0.9934291972193124,
#   0.9959051518902962,
#   0.9983811065612799,
#   0.9983811065612799,
#   0.9922864489096277,
#   0.9945719455289972,
#   0.994286258451576,
#   0.9984763355870869,
#   0.9979049614322445,
#   0.9974288163032092,
#   0.9982858775354728,
#   0.9983811065612799,
#   0.998571564612894,
#   0.9894295781354157,
#   0.9982858775354728,
#   0.9997143129225788,
#   0.9967622131225597,
#   0.9988572516903153,
#   1.0,
#   0.998666793638701,
#   0.9967622131225597,
#   0.9965717550709456,
#   0.9977145033806304,
#   0.9967622131225597,
#   0.9959051518902962,
#   0.9975240453290163,
#   0.9962860679935244,
#   0.9992381677935435,
#   0.9962860679935244,
#   0.9937148842967336,
#   0.9984763355870869,
#   0.9995238548709646,
#   0.9973335872774022,
#   0.9977145033806304],
#  'val_loss': [0.16019452190534636,
#   0.10603221773423932,
#   0.06876327789981257,
#   0.05850878415036608,
#   0.06257950096729804,
#   0.047790457583455875,
#   0.05417136674408208,
#   0.04625333598814905,
#   0.037647665546021676,
#   0.04351374568967995,
#   0.03981835167241198,
#   0.0364153346427801,
#   0.04844300605949353,
#   0.038764590686398814,
#   0.043720992105293344,
#   0.03147707130675289,
#   0.03505982141412625,
#   0.03603674352423034,
#   0.04010978842746805,
#   0.041930327875624326,
#   0.03398176402128725,
#   0.03745992941337384,
#   0.03142798744216138,
#   0.030821815392383458,
#   0.037505333542569796,
#   0.03213804372247647,
#   0.025144904320239386,
#   0.032127597307871014,
#   0.036650485558096656,
#   0.029302200143733484,
#   0.03174515256541781,
#   0.02974828524483283,
#   0.03336431785613637,
#   0.029937588800252837,
#   0.027715860429452732,
#   0.0283844236866571,
#   0.027357173478759995,
#   0.029338378334862435,
#   0.02912218507024756,
#   0.03527827971900644,
#   0.031076860436323014,
#   0.02923917639444963,
#   0.027582507232860237,
#   0.02429902370495256,
#   0.03013089949804866,
#   0.028050561338551976,
#   0.030752599803963675,
#   0.028936129878275096,
#   0.02869649403199384,
#   0.02961881002331872,
#   0.03354521549825387,
#   0.030998835266853514,
#   0.03463051601482386,
#   0.02888524850343608,
#   0.025120173739428125,
#   0.02381961915816646,
#   0.02491121347934082,
#   0.031629333198493856,
#   0.03001692299889824,
#   0.028701763370455328,
#   0.03126738778505982,
#   0.0326199927970513,
#   0.02744108412139626,
#   0.0255987710472916,
#   0.023264022169380703,
#   0.02662780446434309,
#   0.03946629356783391,
#   0.029430574478729713,
#   0.033892529591685164,
#   0.02646729980902323,
#   0.031911752396263184,
#   0.027644645576153627,
#   0.028366738194811413,
#   0.022561881103320046,
#   0.027779834160835227,
#   0.027251145959069783,
#   0.03205379923562181,
#   0.028385184933061035,
#   0.02449881954393773,
#   0.03296784286556596,
#   0.028225012654332783,
#   0.024311367812333628,
#   0.03291373591795987,
#   0.022643998652611942,
#   0.019671872207916087,
#   0.023620771074307743,
#   0.024819692100969737,
#   0.032014133178348524,
#   0.030319370903783817,
#   0.0357134078385901,
#   0.028494496413887564,
#   0.0275186377746815,
#   0.024125118657618506,
#   0.02063747175059027,
#   0.022511020460991526,
#   0.029969642144119873,
#   0.0270046443620231,
#   0.02465063144746554,
#   0.023995253969703548,
#   0.022239743535994255],
#  'val_accuracy': [0.8768923164810054,
#   0.9231648100542702,
#   0.9300199942873465,
#   0.9323050556983719,
#   0.9237360754070265,
#   0.9257355041416738,
#   0.9251642387889174,
#   0.9311625249928592,
#   0.9403027706369609,
#   0.9197372179377321,
#   0.9283061982290775,
#   0.9334475864038846,
#   0.9057412167952014,
#   0.9303056269637247,
#   0.9343044844330192,
#   0.9394458726078263,
#   0.9271636675235647,
#   0.9394458726078263,
#   0.921165381319623,
#   0.9317337903456155,
#   0.9320194230219937,
#   0.9383033419023136,
#   0.9403027706369609,
#   0.9377320765495573,
#   0.9400171379605827,
#   0.9408740359897172,
#   0.9480148528991716,
#   0.9397315052842045,
#   0.9343044844330192,
#   0.9417309340188518,
#   0.9365895458440445,
#   0.93887460725507,
#   0.9434447300771208,
#   0.9491573836046844,
#   0.9485861182519281,
#   0.9468723221936589,
#   0.9491573836046844,
#   0.9383033419023136,
#   0.9417309340188518,
#   0.937160811196801,
#   0.9294487289345901,
#   0.9448728934590117,
#   0.943730362753499,
#   0.9514424450157098,
#   0.9300199942873465,
#   0.951728077692088,
#   0.9414453013424736,
#   0.9480148528991716,
#   0.9520137103684662,
#   0.9497286489574407,
#   0.9288774635818338,
#   0.940588403313339,
#   0.9374464438731791,
#   0.9428734647243645,
#   0.9445872607826336,
#   0.9505855469865753,
#   0.945444158811768,
#   0.9365895458440445,
#   0.9457297914881463,
#   0.940588403313339,
#   0.9274493001999429,
#   0.9311625249928592,
#   0.9477292202227935,
#   0.9525849757212225,
#   0.9474435875464153,
#   0.9374464438731791,
#   0.9294487289345901,
#   0.9403027706369609,
#   0.9237360754070265,
#   0.9434447300771208,
#   0.9394458726078263,
#   0.9431590974007427,
#   0.9414453013424736,
#   0.9463010568409026,
#   0.9443016281062554,
#   0.9431590974007427,
#   0.9363039131676664,
#   0.9394458726078263,
#   0.9360182804912882,
#   0.9434447300771208,
#   0.9528706083976007,
#   0.9505855469865753,
#   0.9343044844330192,
#   0.9502999143101971,
#   0.9525849757212225,
#   0.9363039131676664,
#   0.945444158811768,
#   0.9423021993716081,
#   0.9334475864038846,
#   0.9343044844330192,
#   0.9431590974007427,
#   0.9417309340188518,
#   0.9403027706369609,
#   0.9463010568409026,
#   0.9325906883747501,
#   0.93887460725507,
#   0.9488717509283062,
#   0.945444158811768,
#   0.9428734647243645,
#   0.950014281633819],
#  'model_name': 'Pretrained Inception-v3',
#  'best_val_accuracy': 0.9528706083976007}

# %% [markdown]
# Let's plot the above matrices for visualization.

# %%
def plot_history(history):

    epochs = range(1, len(history['train_loss']) + 1)



    plt.figure(figsize=(12, 4))



    plt.subplot(1, 2, 1)

    plt.plot(epochs, history['train_loss'], label='Train Loss')

    plt.plot(epochs, history['val_loss'], label='Validation Loss')

    plt.xlabel('Epochs')

    plt.ylabel('Loss')

    plt.title('Train and Validation Loss')

    plt.legend()



    plt.subplot(1, 2, 2)

    plt.plot(epochs, history['train_accuracy'], label='Train Accuracy')

    plt.plot(epochs, history['val_accuracy'], label='Validation Accuracy')

    plt.xlabel('Epochs')

    plt.ylabel('Accuracy')

    plt.title('Train and Validation Accuracy')

    plt.legend()



    plt.show()



plot_history(history)

# %% [markdown]
# So from above we can see that our pre-trained model performs really good:
#
# * The training accuracy approaches 1.0 (100%) at the end of the training.
#
# * Wherelese, the validation accuracy fluctuates but ends around 0.95 (95%).

# %% [markdown]
# # Testing the model:-

# %% [markdown]
# **Let's first test our model on a single image picked randomly.**

# %%
# Load the best model

model.load_state_dict(torch.load(best_model_path))

model.eval()  # Set model to evaluation mode



# Create test loader (assumes a function `create_dataloader` exists)

test_loader = create_dataloader(loader_type='test')



# Evaluate model on the test set

test_correct = 0

test_total = 0



with torch.no_grad():  # Disable gradient calculation for testing

    for inputs, targets in test_loader:

        inputs, targets = inputs.to(device), targets.to(device)

        outputs = model(inputs)

        _, predicted = outputs.max(1)  # Get predictions

        test_total += targets.size(0)

        test_correct += predicted.eq(targets).sum().item()



test_accuracy = test_correct / test_total

print(f'Test Accuracy: {test_accuracy:.4f}')



# Choose a random image from the test loader and plot it

dataiter = iter(test_loader)

images, labels = next(dataiter)  # Use next() to get a batch



# Randomly select an image from the batch

random_index = np.random.randint(0, len(images))

image = images[random_index]

label = labels[random_index]



# Move the image to the appropriate device and make prediction

image_tensor = image.unsqueeze(0).to(device)

output = model(image_tensor)

_, predicted_class = output.max(1)



# Convert image to CPU and detach for plotting

image = image.cpu().numpy().transpose((1, 2, 0))  # Convert to numpy array for plotting

image = np.clip(image, 0, 1)  # Normalize pixel values for display



# Plot the image

plt.imshow(image)

plt.title(f'Predicted Class: {predicted_class.item()}, True Class: {label.item()}')

plt.show()



# Print the predicted class

print(f"Predicted Class: {predicted_class.item()}")

print(f"True Class: {label.item()}")
# Out:
# /tmp/ipykernel_23/3846559363.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# Test Accuracy: 0.9461
# Predicted Class: 8
# True Class: 1

# %% [markdown]
# **Now, let's test on a batch of images picked randomly.**

# %%
# Evaluate the model on a batch of test images

dataiter = iter(test_loader)

images, labels = next(dataiter)  # Get a batch of images and their labels



# Move images and labels to the appropriate device

images, labels = images.to(device), labels.to(device)



# Make predictions on the batch

outputs = model(images)

_, predicted_classes = outputs.max(1)



# Convert images back to CPU for visualization

images = images.cpu().numpy().transpose((0, 2, 3, 1))  # Convert to numpy array (N, H, W, C)

images = np.clip(images, 0, 1)  # Normalize pixel values for display



# Plot multiple images with their predicted and true labels

num_images_to_plot = 5  # Number of images to display

fig, axes = plt.subplots(1, num_images_to_plot, figsize=(15, 5))



for idx in range(num_images_to_plot):

    axes[idx].imshow(images[idx])

    axes[idx].set_title(

        f"Predicted: {predicted_classes[idx].item()}\nTrue: {labels[idx].item()}"

    )

    axes[idx].axis('off')



plt.tight_layout()

plt.show()



# Print predictions and true labels for the displayed images

for idx in range(num_images_to_plot):

    print(f"Image {idx + 1}:")

    print(f"    Predicted Class: {predicted_classes[idx].item()}")

    print(f"    True Class: {labels[idx].item()}")
# Out:
# Image 1:
#     Predicted Class: 1
#     True Class: 0
# Image 2:
#     Predicted Class: 0
#     True Class: 0
# Image 3:
#     Predicted Class: 0
#     True Class: 0
# Image 4:
#     Predicted Class: 0
#     True Class: 0
# Image 5:
#     Predicted Class: 5
#     True Class: 0
