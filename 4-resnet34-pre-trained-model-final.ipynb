# %% [markdown]
# In **this 4th notebook**, we'll implement a **pre-trained ResNet-34 model** to test on our dataset in place of ResNet-50 models. We'll also fine tune it and compare the results.

# %% [markdown]
# ##Loading the dataset

# %% [markdown]
# The images and datasets are provided on GitHub here: https://github.com/AlexOlsen/DeepWeeds/tree/master . And the labels are provided here: https://github.com/AlexOlsen/DeepWeeds/tree/master/labels .
#
#
#
# On the other hand, they can also be downloaded from TesnsorFlow dataset hub: https://www.tensorflow.org/datasets/catalog/deep_weeds .
#
#
#
# As we've run most of our models on Kaggle, so we've downloaded the datasets from GitHub and loaded all on the kaggle account.

# %%
pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->torchvision) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->torchvision) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow_datasets as tfds

import logging

from zipfile import ZipFile

import os

import sys

import shutil

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

#from utils.events import download_google_drive_file

# %%
import os

os.listdir('/kaggle/input/deepweeds-image-classification')
# Out:
# ['train_subset1.csv',
#  'test_subset1.csv',
#  'val_subset0.csv',
#  'test_subset0.csv',
#  'train_subset0.csv',
#  'images',
#  'val_subset1.csv',
#  'labels.csv']

# %%
import pandas as pd

import os

from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split

from PIL import Image

import torch

from torchvision import transforms

import torchvision

from torchvision import models

import torch.nn as nn

import torch.optim as optim

# %% [markdown]
# ##Applying Image Transformations

# %% [markdown]
# * We'll, now, apply **image transformations** to prepare the data for training and testing in our deep learning model. These transformations help to improve the model’s performance and generalization
#
#
#
# * Additionally, in both phases, we **normalize** the images using the mean and standard deviation values derived from the ImageNet dataset. This normalization step adjusts the pixel values to a common scale, which can expedite the training process and enhance model performance.

# %%
# Custom dataset class

class ImageDataset(Dataset):

    def __init__(self, csv_file, img_dir, transform=None):

        self.data_frame = pd.read_csv(csv_file)

        self.img_dir = img_dir

        self.transform = transform



    def __len__(self):

        return len(self.data_frame)



    def __getitem__(self, idx):

        img_name = os.path.join(self.img_dir, self.data_frame.iloc[idx, 0])

        image = Image.open(img_name)

        label = int(self.data_frame.iloc[idx, 1])



        if self.transform:

            image = self.transform(image)



        return image, label



# Load the CSV file

train_csv_file = '/kaggle/input/deepweeds-image-classification/train_subset0.csv'  # Replace with your actual path

test_csv_file = '/kaggle/input/deepweeds-image-classification/test_subset0.csv'  # Replace with your actual path

val_csv_file = '/kaggle/input/deepweeds-image-classification/val_subset0.csv'  # Replace with your actual path

img_dir = '/kaggle/input/deepweeds-image-classification/images'  # Replace with your images directory



# Image transformations (resize, normalization, etc.)

transform = transforms.Compose([

    transforms.Resize((256, 256)),  # Resizing to 256x256, you can adjust this

    transforms.ToTensor(),  #Converts the image into a PyTorch tensor and scales pixel values to [0, 1]

    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])     #Normalizes the image with a mean and standard deviation of [0.5, 0.5, 0.5] for the three RGB channels.

  ])



# Create the train and test datasets

train_dataset = ImageDataset(csv_file=train_csv_file, img_dir=img_dir, transform=transform)
test_dataset = ImageDataset(csv_file=test_csv_file, img_dir=img_dir, transform=transform)
val_dataset = ImageDataset(csv_file=val_csv_file, img_dir=img_dir, transform=transform)


# Create DataLoaders for batching

def create_dataloader(loader_type):

  if loader_type=='train':

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

    print(f"len train_loader {len(train_loader)}")

    return train_loader

  elif loader_type=='val':

    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

    return val_loader

  else:

    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    return test_loader

# %%
# Checking & printing the size of datasets

num_train_samples = len(train_dataset)

num_val_samples = len(val_dataset)

num_test_samples = len(test_dataset)

print(f"Number of training samples: {num_train_samples}")

print(f"Number of validation samples: {num_val_samples}")

print(f"Number of testing samples: {num_test_samples}")
# Out:
# Number of training samples: 10501
# Number of validation samples: 3501
# Number of testing samples: 3507

# %%
import json   # For saving the history


# Load the pre-trained ResNet-34 model:

model = models.resnet34(pretrained=True)

num_ftrs = model.fc.in_features

model.fc = nn.Linear(num_ftrs, 9)  # Adjust for CIFAR-10 (8 classes)


# Loss function and optimizer:

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)


# Training History and Device Setup:
# Initialize history dictionary
history = {

        'train_loss': [],

        'train_accuracy': [],

        'val_loss': [],

        'val_accuracy': []

    }

# Add model name to the history dictionary
history['model_name'] = 'Pretrained ResNet34'  # Change the name for each model in each notebook


best_val_accuracy = 0.0

best_model_path = "best_model_pretrained_resnet34.pth"

# Device Setup

device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = model.to(device)


# Dataloaders:

train_loader = create_dataloader(loader_type='train')
val_loader = create_dataloader(loader_type='val')


# Training loop:

for epoch in range(100):                      # You can adjust the number of epochs

          #training phase-
          model.train()

          running_loss = 0.0

          train_correct = 0

          train_total = 0

          #batch processing
          for i, (inputs, targets) in enumerate(train_loader):

              inputs, targets = inputs.to(device), targets.to(device)

              optimizer.zero_grad()

              outputs = model(inputs)

              _, predicted = outputs.max(1)

              loss = criterion(outputs, targets)

              loss.backward()

              optimizer.step()

              #training metrics-
              running_loss += loss.item()

              train_total += targets.size(0)

              train_correct += predicted.eq(targets).sum().item()


              if i % 100 == 0:

                  print(f'Epoch [{epoch+1}/100], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')


          #training metrics-
          train_loss = running_loss / len(train_loader)

          train_accuracy = train_correct / train_total

          history['train_loss'].append(train_loss)

          history['train_accuracy'].append(train_accuracy)


          # Validation loop:

          model.eval()

          val_loss = 0.0

          val_correct = 0

          val_total = 0

          with torch.no_grad():

            for inputs, targets in val_loader:

              inputs, targets = inputs.to(device), targets.to(device)

              outputs = model(inputs)

              _, predicted = outputs.max(1)

              loss = criterion(outputs, predicted)



              val_loss += loss.item()

              val_total += targets.size(0)

              val_correct += predicted.eq(targets).sum().item()



          # Calculate accuracy

          val_loss /= len(val_loader)

          val_accuracy = val_correct / val_total

          history['val_loss'].append(val_loss)

          history['val_accuracy'].append(val_accuracy)



          print(f'Epoch [{epoch+1}/100], Validation Accuracy: {val_accuracy:.4f}, Train Accuracy: {train_accuracy:.4f}')


           # Save Best Model / Model Checkpointing:
          if val_accuracy > best_val_accuracy:

            best_val_accuracy = val_accuracy
            history['best_val_accuracy'] = best_val_accuracy

            torch.save(model.state_dict(), best_model_path)

            print(f"New best model saved with Validation Accuracy: {val_accuracy:.4f}")


# Save the history as a JSON file:
history_file = 'history_pretrained_resnet34.json'   # Change the filename for each model in each notebook
with open(history_file, 'w') as f:
    json.dump(history, f)

print(f"Training history saved to {history_file}")
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 233MB/s]
# len train_loader 329
# Epoch [1/100], Step [1/329], Loss: 2.1626
# Epoch [1/100], Step [101/329], Loss: 0.3687
# Epoch [1/100], Step [201/329], Loss: 0.6782
# Epoch [1/100], Step [301/329], Loss: 0.4380
# Epoch [1/100], Validation Accuracy: 0.8492, Train Accuracy: 0.8141
# New best model saved with Validation Accuracy: 0.8492
# Epoch [2/100], Step [1/329], Loss: 0.1471
# Epoch [2/100], Step [101/329], Loss: 0.0958
# Epoch [2/100], Step [201/329], Loss: 0.1924
# Epoch [2/100], Step [301/329], Loss: 0.0808
# Epoch [2/100], Validation Accuracy: 0.9160, Train Accuracy: 0.9371
# New best model saved with Validation Accuracy: 0.9160
# Epoch [3/100], Step [1/329], Loss: 0.0330
# Epoch [3/100], Step [101/329], Loss: 0.0596
# Epoch [3/100], Step [201/329], Loss: 0.0425
# Epoch [3/100], Step [301/329], Loss: 0.0088
# Epoch [3/100], Validation Accuracy: 0.9006, Train Accuracy: 0.9699
# Epoch [4/100], Step [1/329], Loss: 0.0379
# Epoch [4/100], Step [101/329], Loss: 0.0105
# Epoch [4/100], Step [201/329], Loss: 0.0152
# Epoch [4/100], Step [301/329], Loss: 0.0254
# Epoch [4/100], Validation Accuracy: 0.9209, Train Accuracy: 0.9833
# New best model saved with Validation Accuracy: 0.9209
# Epoch [5/100], Step [1/329], Loss: 0.0105
# Epoch [5/100], Step [101/329], Loss: 0.0833
# Epoch [5/100], Step [201/329], Loss: 0.1204
# Epoch [5/100], Step [301/329], Loss: 0.0904
# Epoch [5/100], Validation Accuracy: 0.9100, Train Accuracy: 0.9768
# Epoch [6/100], Step [1/329], Loss: 0.2383
# Epoch [6/100], Step [101/329], Loss: 0.1037
# Epoch [6/100], Step [201/329], Loss: 0.1302
# Epoch [6/100], Step [301/329], Loss: 0.0247
# Epoch [6/100], Validation Accuracy: 0.9083, Train Accuracy: 0.9834
# Epoch [7/100], Step [1/329], Loss: 0.0602
# Epoch [7/100], Step [101/329], Loss: 0.1208
# Epoch [7/100], Step [201/329], Loss: 0.0068
# Epoch [7/100], Step [301/329], Loss: 0.0058
# Epoch [7/100], Validation Accuracy: 0.9243, Train Accuracy: 0.9846
# New best model saved with Validation Accuracy: 0.9243
# Epoch [8/100], Step [1/329], Loss: 0.0280
# Epoch [8/100], Step [101/329], Loss: 0.0356
# Epoch [8/100], Step [201/329], Loss: 0.1948
# Epoch [8/100], Step [301/329], Loss: 0.1023
# Epoch [8/100], Validation Accuracy: 0.9249, Train Accuracy: 0.9791
# New best model saved with Validation Accuracy: 0.9249
# Epoch [9/100], Step [1/329], Loss: 0.0476
# Epoch [9/100], Step [101/329], Loss: 0.0432
# Epoch [9/100], Step [201/329], Loss: 0.0843
# Epoch [9/100], Step [301/329], Loss: 0.0100
# Epoch [9/100], Validation Accuracy: 0.9189, Train Accuracy: 0.9858
# Epoch [10/100], Step [1/329], Loss: 0.0057
# Epoch [10/100], Step [101/329], Loss: 0.0838
# Epoch [10/100], Step [201/329], Loss: 0.0084
# Epoch [10/100], Step [301/329], Loss: 0.0385
# Epoch [10/100], Validation Accuracy: 0.9246, Train Accuracy: 0.9890
# Epoch [11/100], Step [1/329], Loss: 0.0147
# Epoch [11/100], Step [101/329], Loss: 0.1009
# Epoch [11/100], Step [201/329], Loss: 0.0085
# Epoch [11/100], Step [301/329], Loss: 0.0241
# Epoch [11/100], Validation Accuracy: 0.9169, Train Accuracy: 0.9928
# Epoch [12/100], Step [1/329], Loss: 0.0058
# Epoch [12/100], Step [101/329], Loss: 0.0109
# Epoch [12/100], Step [201/329], Loss: 0.0066
# Epoch [12/100], Step [301/329], Loss: 0.0540
# Epoch [12/100], Validation Accuracy: 0.9297, Train Accuracy: 0.9933
# New best model saved with Validation Accuracy: 0.9297
# Epoch [13/100], Step [1/329], Loss: 0.1131
# Epoch [13/100], Step [101/329], Loss: 0.0016
# Epoch [13/100], Step [201/329], Loss: 0.0014
# Epoch [13/100], Step [301/329], Loss: 0.0044
# Epoch [13/100], Validation Accuracy: 0.9357, Train Accuracy: 0.9963
# New best model saved with Validation Accuracy: 0.9357
# Epoch [14/100], Step [1/329], Loss: 0.0006
# Epoch [14/100], Step [101/329], Loss: 0.0098
# Epoch [14/100], Step [201/329], Loss: 0.0282
# Epoch [14/100], Step [301/329], Loss: 0.0149
# Epoch [14/100], Validation Accuracy: 0.9029, Train Accuracy: 0.9917
# Epoch [15/100], Step [1/329], Loss: 0.0215
# Epoch [15/100], Step [101/329], Loss: 0.0133
# Epoch [15/100], Step [201/329], Loss: 0.0981
# Epoch [15/100], Step [301/329], Loss: 0.0318
# Epoch [15/100], Validation Accuracy: 0.9314, Train Accuracy: 0.9768
# Epoch [16/100], Step [1/329], Loss: 0.0295
# Epoch [16/100], Step [101/329], Loss: 0.0076
# Epoch [16/100], Step [201/329], Loss: 0.0024
# Epoch [16/100], Step [301/329], Loss: 0.0325
# Epoch [16/100], Validation Accuracy: 0.9374, Train Accuracy: 0.9920
# New best model saved with Validation Accuracy: 0.9374
# Epoch [17/100], Step [1/329], Loss: 0.0047
# Epoch [17/100], Step [101/329], Loss: 0.0813
# Epoch [17/100], Step [201/329], Loss: 0.0363
# Epoch [17/100], Step [301/329], Loss: 0.0149
# Epoch [17/100], Validation Accuracy: 0.9354, Train Accuracy: 0.9926
# Epoch [18/100], Step [1/329], Loss: 0.0019
# Epoch [18/100], Step [101/329], Loss: 0.0587
# Epoch [18/100], Step [201/329], Loss: 0.0273
# Epoch [18/100], Step [301/329], Loss: 0.0560
# Epoch [18/100], Validation Accuracy: 0.9229, Train Accuracy: 0.9915
# Epoch [19/100], Step [1/329], Loss: 0.0274
# Epoch [19/100], Step [101/329], Loss: 0.0034
# Epoch [19/100], Step [201/329], Loss: 0.0079
# Epoch [19/100], Step [301/329], Loss: 0.0495
# Epoch [19/100], Validation Accuracy: 0.9066, Train Accuracy: 0.9914
# Epoch [20/100], Step [1/329], Loss: 0.0088
# Epoch [20/100], Step [101/329], Loss: 0.0019
# Epoch [20/100], Step [201/329], Loss: 0.0222
# Epoch [20/100], Step [301/329], Loss: 0.0043
# Epoch [20/100], Validation Accuracy: 0.9243, Train Accuracy: 0.9943
# Epoch [21/100], Step [1/329], Loss: 0.0091
# Epoch [21/100], Step [101/329], Loss: 0.0006
# Epoch [21/100], Step [201/329], Loss: 0.0041
# Epoch [21/100], Step [301/329], Loss: 0.0053
# Epoch [21/100], Validation Accuracy: 0.9192, Train Accuracy: 0.9912
# Epoch [22/100], Step [1/329], Loss: 0.0004
# Epoch [22/100], Step [101/329], Loss: 0.0032
# Epoch [22/100], Step [201/329], Loss: 0.0033
# Epoch [22/100], Step [301/329], Loss: 0.0543
# Epoch [22/100], Validation Accuracy: 0.9263, Train Accuracy: 0.9879
# Epoch [23/100], Step [1/329], Loss: 0.2110
# Epoch [23/100], Step [101/329], Loss: 0.0052
# Epoch [23/100], Step [201/329], Loss: 0.0035
# Epoch [23/100], Step [301/329], Loss: 0.0100
# Epoch [23/100], Validation Accuracy: 0.9340, Train Accuracy: 0.9863
# Epoch [24/100], Step [1/329], Loss: 0.0163
# Epoch [24/100], Step [101/329], Loss: 0.0060
# Epoch [24/100], Step [201/329], Loss: 0.0069
# Epoch [24/100], Step [301/329], Loss: 0.0026
# Epoch [24/100], Validation Accuracy: 0.9354, Train Accuracy: 0.9960
# Epoch [25/100], Step [1/329], Loss: 0.0014
# Epoch [25/100], Step [101/329], Loss: 0.0013
# Epoch [25/100], Step [201/329], Loss: 0.0005
# Epoch [25/100], Step [301/329], Loss: 0.0002
# Epoch [25/100], Validation Accuracy: 0.9472, Train Accuracy: 0.9990
# New best model saved with Validation Accuracy: 0.9472
# Epoch [26/100], Step [1/329], Loss: 0.0007
# Epoch [26/100], Step [101/329], Loss: 0.0016
# Epoch [26/100], Step [201/329], Loss: 0.0020
# Epoch [26/100], Step [301/329], Loss: 0.0264
# Epoch [26/100], Validation Accuracy: 0.9340, Train Accuracy: 0.9986
# Epoch [27/100], Step [1/329], Loss: 0.0033
# Epoch [27/100], Step [101/329], Loss: 0.0024
# Epoch [27/100], Step [201/329], Loss: 0.0003
# Epoch [27/100], Step [301/329], Loss: 0.0170
# Epoch [27/100], Validation Accuracy: 0.9120, Train Accuracy: 0.9962
# Epoch [28/100], Step [1/329], Loss: 0.0139
# Epoch [28/100], Step [101/329], Loss: 0.0022
# Epoch [28/100], Step [201/329], Loss: 0.0484
# Epoch [28/100], Step [301/329], Loss: 0.0004
# Epoch [28/100], Validation Accuracy: 0.9035, Train Accuracy: 0.9932
# Epoch [29/100], Step [1/329], Loss: 0.2023
# Epoch [29/100], Step [101/329], Loss: 0.0202
# Epoch [29/100], Step [201/329], Loss: 0.0331
# Epoch [29/100], Step [301/329], Loss: 0.0019
# Epoch [29/100], Validation Accuracy: 0.9229, Train Accuracy: 0.9891
# Epoch [30/100], Step [1/329], Loss: 0.0128
# Epoch [30/100], Step [101/329], Loss: 0.0190
# Epoch [30/100], Step [201/329], Loss: 0.0007
# Epoch [30/100], Step [301/329], Loss: 0.0493
# Epoch [30/100], Validation Accuracy: 0.9286, Train Accuracy: 0.9903
# Epoch [31/100], Step [1/329], Loss: 0.0032
# Epoch [31/100], Step [101/329], Loss: 0.0035
# Epoch [31/100], Step [201/329], Loss: 0.0034
# Epoch [31/100], Step [301/329], Loss: 0.0014
# Epoch [31/100], Validation Accuracy: 0.9357, Train Accuracy: 0.9970
# Epoch [32/100], Step [1/329], Loss: 0.0049
# Epoch [32/100], Step [101/329], Loss: 0.0012
# Epoch [32/100], Step [201/329], Loss: 0.0422
# Epoch [32/100], Step [301/329], Loss: 0.0064
# Epoch [32/100], Validation Accuracy: 0.9360, Train Accuracy: 0.9956
# Epoch [33/100], Step [1/329], Loss: 0.0040
# Epoch [33/100], Step [101/329], Loss: 0.0054
# Epoch [33/100], Step [201/329], Loss: 0.0154
# Epoch [33/100], Step [301/329], Loss: 0.0068
# Epoch [33/100], Validation Accuracy: 0.9057, Train Accuracy: 0.9904
# Epoch [34/100], Step [1/329], Loss: 0.0197
# Epoch [34/100], Step [101/329], Loss: 0.0038
# Epoch [34/100], Step [201/329], Loss: 0.0209
# Epoch [34/100], Step [301/329], Loss: 0.0001
# Epoch [34/100], Validation Accuracy: 0.9380, Train Accuracy: 0.9944
# Epoch [35/100], Step [1/329], Loss: 0.0001
# Epoch [35/100], Step [101/329], Loss: 0.0011
# Epoch [35/100], Step [201/329], Loss: 0.0083
# Epoch [35/100], Step [301/329], Loss: 0.0009
# Epoch [35/100], Validation Accuracy: 0.9286, Train Accuracy: 0.9988
# Epoch [36/100], Step [1/329], Loss: 0.0019
# Epoch [36/100], Step [101/329], Loss: 0.0029
# Epoch [36/100], Step [201/329], Loss: 0.0295
# Epoch [36/100], Step [301/329], Loss: 0.0582
# Epoch [36/100], Validation Accuracy: 0.9309, Train Accuracy: 0.9921
# Epoch [37/100], Step [1/329], Loss: 0.0886
# Epoch [37/100], Step [101/329], Loss: 0.0038
# Epoch [37/100], Step [201/329], Loss: 0.0003
# Epoch [37/100], Step [301/329], Loss: 0.0048
# Epoch [37/100], Validation Accuracy: 0.9326, Train Accuracy: 0.9973
# Epoch [38/100], Step [1/329], Loss: 0.0044
# Epoch [38/100], Step [101/329], Loss: 0.0004
# Epoch [38/100], Step [201/329], Loss: 0.0104
# Epoch [38/100], Step [301/329], Loss: 0.0005
# Epoch [38/100], Validation Accuracy: 0.9300, Train Accuracy: 0.9991
# Epoch [39/100], Step [1/329], Loss: 0.0007
# Epoch [39/100], Step [101/329], Loss: 0.0018
# Epoch [39/100], Step [201/329], Loss: 0.0018
# Epoch [39/100], Step [301/329], Loss: 0.0016
# Epoch [39/100], Validation Accuracy: 0.8903, Train Accuracy: 0.9950
# Epoch [40/100], Step [1/329], Loss: 0.0003
# Epoch [40/100], Step [101/329], Loss: 0.0023
# Epoch [40/100], Step [201/329], Loss: 0.0071
# Epoch [40/100], Step [301/329], Loss: 0.0001
# Epoch [40/100], Validation Accuracy: 0.9329, Train Accuracy: 0.9924
# Epoch [41/100], Step [1/329], Loss: 0.0003
# Epoch [41/100], Step [101/329], Loss: 0.0006
# Epoch [41/100], Step [201/329], Loss: 0.0073
# Epoch [41/100], Step [301/329], Loss: 0.0058
# Epoch [41/100], Validation Accuracy: 0.9089, Train Accuracy: 0.9960
# Epoch [42/100], Step [1/329], Loss: 0.0082
# Epoch [42/100], Step [101/329], Loss: 0.0005
# Epoch [42/100], Step [201/329], Loss: 0.0003
# Epoch [42/100], Step [301/329], Loss: 0.0001
# Epoch [42/100], Validation Accuracy: 0.9437, Train Accuracy: 0.9987
# Epoch [43/100], Step [1/329], Loss: 0.0000
# Epoch [43/100], Step [101/329], Loss: 0.0009
# Epoch [43/100], Step [201/329], Loss: 0.0007
# Epoch [43/100], Step [301/329], Loss: 0.0271
# Epoch [43/100], Validation Accuracy: 0.9263, Train Accuracy: 0.9953
# Epoch [44/100], Step [1/329], Loss: 0.0015
# Epoch [44/100], Step [101/329], Loss: 0.0025
# Epoch [44/100], Step [201/329], Loss: 0.0042
# Epoch [44/100], Step [301/329], Loss: 0.0811
# Epoch [44/100], Validation Accuracy: 0.8940, Train Accuracy: 0.9948
# Epoch [45/100], Step [1/329], Loss: 0.0071
# Epoch [45/100], Step [101/329], Loss: 0.0466
# Epoch [45/100], Step [201/329], Loss: 0.0004
# Epoch [45/100], Step [301/329], Loss: 0.0072
# Epoch [45/100], Validation Accuracy: 0.9320, Train Accuracy: 0.9936
# Epoch [46/100], Step [1/329], Loss: 0.0062
# Epoch [46/100], Step [101/329], Loss: 0.0011
# Epoch [46/100], Step [201/329], Loss: 0.0052
# Epoch [46/100], Step [301/329], Loss: 0.0003
# Epoch [46/100], Validation Accuracy: 0.9303, Train Accuracy: 0.9975
# Epoch [47/100], Step [1/329], Loss: 0.0010
# Epoch [47/100], Step [101/329], Loss: 0.0272
# Epoch [47/100], Step [201/329], Loss: 0.0089
# Epoch [47/100], Step [301/329], Loss: 0.0006
# Epoch [47/100], Validation Accuracy: 0.8920, Train Accuracy: 0.9941
# Epoch [48/100], Step [1/329], Loss: 0.0840
# Epoch [48/100], Step [101/329], Loss: 0.0712
# Epoch [48/100], Step [201/329], Loss: 0.0075
# Epoch [48/100], Step [301/329], Loss: 0.0002
# Epoch [48/100], Validation Accuracy: 0.9334, Train Accuracy: 0.9967
# Epoch [49/100], Step [1/329], Loss: 0.0197
# Epoch [49/100], Step [101/329], Loss: 0.0002
# Epoch [49/100], Step [201/329], Loss: 0.0235
# Epoch [49/100], Step [301/329], Loss: 0.0023
# Epoch [49/100], Validation Accuracy: 0.9280, Train Accuracy: 0.9973
# Epoch [50/100], Step [1/329], Loss: 0.0354
# Epoch [50/100], Step [101/329], Loss: 0.0002
# Epoch [50/100], Step [201/329], Loss: 0.0019
# Epoch [50/100], Step [301/329], Loss: 0.0005
# Epoch [50/100], Validation Accuracy: 0.9374, Train Accuracy: 0.9990
# Epoch [51/100], Step [1/329], Loss: 0.0001
# Epoch [51/100], Step [101/329], Loss: 0.0000
# Epoch [51/100], Step [201/329], Loss: 0.0000
# Epoch [51/100], Step [301/329], Loss: 0.0029
# Epoch [51/100], Validation Accuracy: 0.9412, Train Accuracy: 0.9993
# Epoch [52/100], Step [1/329], Loss: 0.0003
# Epoch [52/100], Step [101/329], Loss: 0.0115
# Epoch [52/100], Step [201/329], Loss: 0.0015
# Epoch [52/100], Step [301/329], Loss: 0.0024
# Epoch [52/100], Validation Accuracy: 0.9175, Train Accuracy: 0.9988
# Epoch [53/100], Step [1/329], Loss: 0.0005
# Epoch [53/100], Step [101/329], Loss: 0.0594
# Epoch [53/100], Step [201/329], Loss: 0.1556
# Epoch [53/100], Step [301/329], Loss: 0.0343
# Epoch [53/100], Validation Accuracy: 0.9086, Train Accuracy: 0.9895
# Epoch [54/100], Step [1/329], Loss: 0.0004
# Epoch [54/100], Step [101/329], Loss: 0.0112
# Epoch [54/100], Step [201/329], Loss: 0.0002
# Epoch [54/100], Step [301/329], Loss: 0.0010
# Epoch [54/100], Validation Accuracy: 0.9317, Train Accuracy: 0.9952
# Epoch [55/100], Step [1/329], Loss: 0.0002
# Epoch [55/100], Step [101/329], Loss: 0.0014
# Epoch [55/100], Step [201/329], Loss: 0.0112
# Epoch [55/100], Step [301/329], Loss: 0.0024
# Epoch [55/100], Validation Accuracy: 0.9380, Train Accuracy: 0.9990
# Epoch [56/100], Step [1/329], Loss: 0.0002
# Epoch [56/100], Step [101/329], Loss: 0.0008
# Epoch [56/100], Step [201/329], Loss: 0.2835
# Epoch [56/100], Step [301/329], Loss: 0.0030
# Epoch [56/100], Validation Accuracy: 0.9340, Train Accuracy: 0.9941
# Epoch [57/100], Step [1/329], Loss: 0.0005
# Epoch [57/100], Step [101/329], Loss: 0.0016
# Epoch [57/100], Step [201/329], Loss: 0.0003
# Epoch [57/100], Step [301/329], Loss: 0.0001
# Epoch [57/100], Validation Accuracy: 0.9289, Train Accuracy: 0.9979
# Epoch [58/100], Step [1/329], Loss: 0.0172
# Epoch [58/100], Step [101/329], Loss: 0.0001
# Epoch [58/100], Step [201/329], Loss: 0.0016
# Epoch [58/100], Step [301/329], Loss: 0.0103
# Epoch [58/100], Validation Accuracy: 0.9252, Train Accuracy: 0.9980
# Epoch [59/100], Step [1/329], Loss: 0.0005
# Epoch [59/100], Step [101/329], Loss: 0.0007
# Epoch [59/100], Step [201/329], Loss: 0.0000
# Epoch [59/100], Step [301/329], Loss: 0.0005
# Epoch [59/100], Validation Accuracy: 0.9220, Train Accuracy: 0.9948
# Epoch [60/100], Step [1/329], Loss: 0.0006
# Epoch [60/100], Step [101/329], Loss: 0.0002
# Epoch [60/100], Step [201/329], Loss: 0.0008
# Epoch [60/100], Step [301/329], Loss: 0.0790
# Epoch [60/100], Validation Accuracy: 0.9337, Train Accuracy: 0.9968
# Epoch [61/100], Step [1/329], Loss: 0.0125
# Epoch [61/100], Step [101/329], Loss: 0.0002
# Epoch [61/100], Step [201/329], Loss: 0.0027
# Epoch [61/100], Step [301/329], Loss: 0.0003
# Epoch [61/100], Validation Accuracy: 0.9409, Train Accuracy: 0.9990
# Epoch [62/100], Step [1/329], Loss: 0.0002
# Epoch [62/100], Step [101/329], Loss: 0.0790
# Epoch [62/100], Step [201/329], Loss: 0.0040
# Epoch [62/100], Step [301/329], Loss: 0.0037
# Epoch [62/100], Validation Accuracy: 0.9346, Train Accuracy: 0.9945
# Epoch [63/100], Step [1/329], Loss: 0.0084
# Epoch [63/100], Step [101/329], Loss: 0.0024
# Epoch [63/100], Step [201/329], Loss: 0.0003
# Epoch [63/100], Step [301/329], Loss: 0.0136
# Epoch [63/100], Validation Accuracy: 0.9323, Train Accuracy: 0.9969
# Epoch [64/100], Step [1/329], Loss: 0.0003
# Epoch [64/100], Step [101/329], Loss: 0.0004
# Epoch [64/100], Step [201/329], Loss: 0.0004
# Epoch [64/100], Step [301/329], Loss: 0.0006
# Epoch [64/100], Validation Accuracy: 0.9206, Train Accuracy: 0.9989
# Epoch [65/100], Step [1/329], Loss: 0.0004
# Epoch [65/100], Step [101/329], Loss: 0.0003
# Epoch [65/100], Step [201/329], Loss: 0.0072
# Epoch [65/100], Step [301/329], Loss: 0.3450
# Epoch [65/100], Validation Accuracy: 0.8935, Train Accuracy: 0.9940
# Epoch [66/100], Step [1/329], Loss: 0.0004
# Epoch [66/100], Step [101/329], Loss: 0.0003
# Epoch [66/100], Step [201/329], Loss: 0.0087
# Epoch [66/100], Step [301/329], Loss: 0.0036
# Epoch [66/100], Validation Accuracy: 0.9209, Train Accuracy: 0.9950
# Epoch [67/100], Step [1/329], Loss: 0.0030
# Epoch [67/100], Step [101/329], Loss: 0.0044
# Epoch [67/100], Step [201/329], Loss: 0.0004
# Epoch [67/100], Step [301/329], Loss: 0.0006
# Epoch [67/100], Validation Accuracy: 0.9277, Train Accuracy: 0.9975
# Epoch [68/100], Step [1/329], Loss: 0.0003
# Epoch [68/100], Step [101/329], Loss: 0.0266
# Epoch [68/100], Step [201/329], Loss: 0.0040
# Epoch [68/100], Step [301/329], Loss: 0.0219
# Epoch [68/100], Validation Accuracy: 0.9209, Train Accuracy: 0.9934
# Epoch [69/100], Step [1/329], Loss: 0.0294
# Epoch [69/100], Step [101/329], Loss: 0.0045
# Epoch [69/100], Step [201/329], Loss: 0.0007
# Epoch [69/100], Step [301/329], Loss: 0.0030
# Epoch [69/100], Validation Accuracy: 0.9383, Train Accuracy: 0.9982
# Epoch [70/100], Step [1/329], Loss: 0.0015
# Epoch [70/100], Step [101/329], Loss: 0.0001
# Epoch [70/100], Step [201/329], Loss: 0.0000
# Epoch [70/100], Step [301/329], Loss: 0.0009
# Epoch [70/100], Validation Accuracy: 0.9403, Train Accuracy: 0.9996
# Epoch [71/100], Step [1/329], Loss: 0.0001
# Epoch [71/100], Step [101/329], Loss: 0.0003
# Epoch [71/100], Step [201/329], Loss: 0.0004
# Epoch [71/100], Step [301/329], Loss: 0.0005
# Epoch [71/100], Validation Accuracy: 0.9380, Train Accuracy: 0.9997
# Epoch [72/100], Step [1/329], Loss: 0.0008
# Epoch [72/100], Step [101/329], Loss: 0.0037
# Epoch [72/100], Step [201/329], Loss: 0.0008
# Epoch [72/100], Step [301/329], Loss: 0.0015
# Epoch [72/100], Validation Accuracy: 0.9323, Train Accuracy: 0.9949
# Epoch [73/100], Step [1/329], Loss: 0.0016
# Epoch [73/100], Step [101/329], Loss: 0.0001
# Epoch [73/100], Step [201/329], Loss: 0.0003
# Epoch [73/100], Step [301/329], Loss: 0.0006
# Epoch [73/100], Validation Accuracy: 0.9357, Train Accuracy: 0.9994
# Epoch [74/100], Step [1/329], Loss: 0.0000
# Epoch [74/100], Step [101/329], Loss: 0.0006
# Epoch [74/100], Step [201/329], Loss: 0.0005
# Epoch [74/100], Step [301/329], Loss: 0.0001
# Epoch [74/100], Validation Accuracy: 0.9406, Train Accuracy: 0.9999
# Epoch [75/100], Step [1/329], Loss: 0.0001
# Epoch [75/100], Step [101/329], Loss: 0.0003
# Epoch [75/100], Step [201/329], Loss: 0.0870
# Epoch [75/100], Step [301/329], Loss: 0.0010
# Epoch [75/100], Validation Accuracy: 0.9126, Train Accuracy: 0.9956
# Epoch [76/100], Step [1/329], Loss: 0.0163
# Epoch [76/100], Step [101/329], Loss: 0.0010
# Epoch [76/100], Step [201/329], Loss: 0.0247
# Epoch [76/100], Step [301/329], Loss: 0.0425
# Epoch [76/100], Validation Accuracy: 0.9206, Train Accuracy: 0.9952
# Epoch [77/100], Step [1/329], Loss: 0.0030
# Epoch [77/100], Step [101/329], Loss: 0.0011
# Epoch [77/100], Step [201/329], Loss: 0.0010
# Epoch [77/100], Step [301/329], Loss: 0.0004
# Epoch [77/100], Validation Accuracy: 0.9112, Train Accuracy: 0.9963
# Epoch [78/100], Step [1/329], Loss: 0.0006
# Epoch [78/100], Step [101/329], Loss: 0.0037
# Epoch [78/100], Step [201/329], Loss: 0.0007
# Epoch [78/100], Step [301/329], Loss: 0.0024
# Epoch [78/100], Validation Accuracy: 0.9352, Train Accuracy: 0.9993
# Epoch [79/100], Step [1/329], Loss: 0.0001
# Epoch [79/100], Step [101/329], Loss: 0.0001
# Epoch [79/100], Step [201/329], Loss: 0.0001
# Epoch [79/100], Step [301/329], Loss: 0.0001
# Epoch [79/100], Validation Accuracy: 0.9343, Train Accuracy: 0.9991
# Epoch [80/100], Step [1/329], Loss: 0.0000
# Epoch [80/100], Step [101/329], Loss: 0.0004
# Epoch [80/100], Step [201/329], Loss: 0.0000
# Epoch [80/100], Step [301/329], Loss: 0.0000
# Epoch [80/100], Validation Accuracy: 0.9420, Train Accuracy: 1.0000
# Epoch [81/100], Step [1/329], Loss: 0.0001
# Epoch [81/100], Step [101/329], Loss: 0.0001
# Epoch [81/100], Step [201/329], Loss: 0.0001
# Epoch [81/100], Step [301/329], Loss: 0.0000
# Epoch [81/100], Validation Accuracy: 0.9432, Train Accuracy: 1.0000
# Epoch [82/100], Step [1/329], Loss: 0.0001
# Epoch [82/100], Step [101/329], Loss: 0.0000
# Epoch [82/100], Step [201/329], Loss: 0.0000
# Epoch [82/100], Step [301/329], Loss: 0.0001
# Epoch [82/100], Validation Accuracy: 0.9389, Train Accuracy: 1.0000
# Epoch [83/100], Step [1/329], Loss: 0.0009
# Epoch [83/100], Step [101/329], Loss: 0.0374
# Epoch [83/100], Step [201/329], Loss: 0.2345
# Epoch [83/100], Step [301/329], Loss: 0.0158
# Epoch [83/100], Validation Accuracy: 0.9220, Train Accuracy: 0.9869
# Epoch [84/100], Step [1/329], Loss: 0.0122
# Epoch [84/100], Step [101/329], Loss: 0.0073
# Epoch [84/100], Step [201/329], Loss: 0.0010
# Epoch [84/100], Step [301/329], Loss: 0.0006
# Epoch [84/100], Validation Accuracy: 0.9363, Train Accuracy: 0.9977
# Epoch [85/100], Step [1/329], Loss: 0.0008
# Epoch [85/100], Step [101/329], Loss: 0.0004
# Epoch [85/100], Step [201/329], Loss: 0.0006
# Epoch [85/100], Step [301/329], Loss: 0.0003
# Epoch [85/100], Validation Accuracy: 0.9389, Train Accuracy: 0.9983
# Epoch [86/100], Step [1/329], Loss: 0.0038
# Epoch [86/100], Step [101/329], Loss: 0.0008
# Epoch [86/100], Step [201/329], Loss: 0.0001
# Epoch [86/100], Step [301/329], Loss: 0.0008
# Epoch [86/100], Validation Accuracy: 0.9217, Train Accuracy: 0.9955
# Epoch [87/100], Step [1/329], Loss: 0.0192
# Epoch [87/100], Step [101/329], Loss: 0.0003
# Epoch [87/100], Step [201/329], Loss: 0.0008
# Epoch [87/100], Step [301/329], Loss: 0.0043
# Epoch [87/100], Validation Accuracy: 0.9212, Train Accuracy: 0.9971
# Epoch [88/100], Step [1/329], Loss: 0.0005
# Epoch [88/100], Step [101/329], Loss: 0.0023
# Epoch [88/100], Step [201/329], Loss: 0.0005
# Epoch [88/100], Step [301/329], Loss: 0.0003
# Epoch [88/100], Validation Accuracy: 0.9337, Train Accuracy: 0.9944
# Epoch [89/100], Step [1/329], Loss: 0.0001
# Epoch [89/100], Step [101/329], Loss: 0.0013
# Epoch [89/100], Step [201/329], Loss: 0.0000
# Epoch [89/100], Step [301/329], Loss: 0.0003
# Epoch [89/100], Validation Accuracy: 0.9303, Train Accuracy: 0.9995
# Epoch [90/100], Step [1/329], Loss: 0.0000
# Epoch [90/100], Step [101/329], Loss: 0.0098
# Epoch [90/100], Step [201/329], Loss: 0.0012
# Epoch [90/100], Step [301/329], Loss: 0.0003
# Epoch [90/100], Validation Accuracy: 0.9346, Train Accuracy: 0.9949
# Epoch [91/100], Step [1/329], Loss: 0.0000
# Epoch [91/100], Step [101/329], Loss: 0.0001
# Epoch [91/100], Step [201/329], Loss: 0.0004
# Epoch [91/100], Step [301/329], Loss: 0.0005
# Epoch [91/100], Validation Accuracy: 0.9352, Train Accuracy: 0.9985
# Epoch [92/100], Step [1/329], Loss: 0.0017
# Epoch [92/100], Step [101/329], Loss: 0.0010
# Epoch [92/100], Step [201/329], Loss: 0.0001
# Epoch [92/100], Step [301/329], Loss: 0.0005
# Epoch [92/100], Validation Accuracy: 0.9437, Train Accuracy: 0.9999
# Epoch [93/100], Step [1/329], Loss: 0.0001
# Epoch [93/100], Step [101/329], Loss: 0.0004
# Epoch [93/100], Step [201/329], Loss: 0.0002
# Epoch [93/100], Step [301/329], Loss: 0.0003
# Epoch [93/100], Validation Accuracy: 0.9263, Train Accuracy: 0.9964
# Epoch [94/100], Step [1/329], Loss: 0.0013
# Epoch [94/100], Step [101/329], Loss: 0.0014
# Epoch [94/100], Step [201/329], Loss: 0.0002
# Epoch [94/100], Step [301/329], Loss: 0.0004
# Epoch [94/100], Validation Accuracy: 0.9389, Train Accuracy: 0.9989
# Epoch [95/100], Step [1/329], Loss: 0.0002
# Epoch [95/100], Step [101/329], Loss: 0.0001
# Epoch [95/100], Step [201/329], Loss: 0.0007
# Epoch [95/100], Step [301/329], Loss: 0.0000
# Epoch [95/100], Validation Accuracy: 0.9257, Train Accuracy: 0.9985
# Epoch [96/100], Step [1/329], Loss: 0.0005
# Epoch [96/100], Step [101/329], Loss: 0.0002
# Epoch [96/100], Step [201/329], Loss: 0.0002
# Epoch [96/100], Step [301/329], Loss: 0.0006
# Epoch [96/100], Validation Accuracy: 0.9177, Train Accuracy: 0.9993
# Epoch [97/100], Step [1/329], Loss: 0.0013
# Epoch [97/100], Step [101/329], Loss: 0.0002
# Epoch [97/100], Step [201/329], Loss: 0.0070
# Epoch [97/100], Step [301/329], Loss: 0.0148
# Epoch [97/100], Validation Accuracy: 0.9346, Train Accuracy: 0.9992
# Epoch [98/100], Step [1/329], Loss: 0.0003
# Epoch [98/100], Step [101/329], Loss: 0.0002
# Epoch [98/100], Step [201/329], Loss: 0.0000
# Epoch [98/100], Step [301/329], Loss: 0.0022
# Epoch [98/100], Validation Accuracy: 0.9306, Train Accuracy: 0.9985
# Epoch [99/100], Step [1/329], Loss: 0.0001
# Epoch [99/100], Step [101/329], Loss: 0.0001
# Epoch [99/100], Step [201/329], Loss: 0.0004
# Epoch [99/100], Step [301/329], Loss: 0.0003
# Epoch [99/100], Validation Accuracy: 0.9286, Train Accuracy: 0.9951
# Epoch [100/100], Step [1/329], Loss: 0.0004
# Epoch [100/100], Step [101/329], Loss: 0.0005
# Epoch [100/100], Step [201/329], Loss: 0.0002
# Epoch [100/100], Step [301/329], Loss: 0.0005
# Epoch [100/100], Validation Accuracy: 0.9363, Train Accuracy: 0.9987
# Training history saved to history_pretrained_resnet34.json

# %%
history
# Out:
# {'train_loss': [0.5544669066066076,
#   0.19285626267295297,
#   0.09149474328196973,
#   0.0545628648874064,
#   0.06669849026622675,
#   0.0546000915714667,
#   0.05019075255791478,
#   0.06864869185386503,
#   0.04765872160782386,
#   0.03799675711420702,
#   0.023526169957683668,
#   0.02136680035672142,
#   0.015233072575385538,
#   0.029166484548318224,
#   0.07394090216284148,
#   0.02565453583111004,
#   0.026483739273499493,
#   0.028071164420758455,
#   0.026382722984840186,
#   0.019852444923010096,
#   0.028393387401990995,
#   0.039917644953686396,
#   0.041827441849547654,
#   0.013002702906267084,
#   0.004782989657785472,
#   0.006167473046929649,
#   0.014752338139677674,
#   0.02499785296236608,
#   0.03554871930732989,
#   0.0270221332459828,
#   0.010550422140984162,
#   0.01246027872183535,
#   0.028820847721385066,
#   0.01994069968191001,
#   0.004735402854801351,
#   0.02253783292600492,
#   0.00856924517101684,
#   0.0033489479550647358,
#   0.012662418706187858,
#   0.021346602887692783,
#   0.011507155648232749,
#   0.005208777068924133,
#   0.015401267948176317,
#   0.01541020305737737,
#   0.01738537500512388,
#   0.00998429279617143,
#   0.016742095486825113,
#   0.011508847502772172,
#   0.007645630964132325,
#   0.004738309973114891,
#   0.0026128901595381445,
#   0.004209033740957692,
#   0.030642840934567553,
#   0.01541221484221972,
#   0.007062984023138672,
#   0.022212002974017795,
#   0.008203549114197071,
#   0.007813331656894235,
#   0.016134430946496546,
#   0.009228805435837248,
#   0.005790186392242866,
#   0.018812480903161875,
#   0.010213097664154288,
#   0.003919367607276839,
#   0.021638353587241275,
#   0.01638045710521612,
#   0.01081525355928086,
#   0.022587445287086463,
#   0.006757702376760674,
#   0.0014571139194933527,
#   0.007417182479105088,
#   0.018123961749306076,
#   0.003549407467798365,
#   0.0017904516159645974,
#   0.01376688966700048,
#   0.013537153762646336,
#   0.013091252948992832,
#   0.0035995029005330653,
#   0.002062365829080983,
#   0.0005481121787282846,
#   0.000332349028725748,
#   0.0005497316680425255,
#   0.043460444999735844,
#   0.007691157329930384,
#   0.00711462071047479,
#   0.016425516024833848,
#   0.015532778152822183,
#   0.017606903679565758,
#   0.0054118183800414745,
#   0.017525960009677426,
#   0.0037410550449282092,
#   0.001625923927113146,
#   0.012324065895962254,
#   0.0036519609790520696,
#   0.006200469516920126,
#   0.0031701375606578088,
#   0.0031071147642032773,
#   0.005321237411607258,
#   0.015597014905797329,
#   0.005530079028223256],
#  'train_accuracy': [0.8141129416246072,
#   0.9371488429673365,
#   0.9699076278449671,
#   0.9833349204837635,
#   0.9767641177030759,
#   0.9834301495095705,
#   0.9845728978192553,
#   0.9791448433482526,
#   0.9858108751547472,
#   0.9890486620321874,
#   0.992762594038663,
#   0.9933339681935054,
#   0.9962860679935244,
#   0.9917150747547853,
#   0.9767641177030759,
#   0.9920007618322064,
#   0.9925721359870489,
#   0.9915246167031712,
#   0.9914293876773641,
#   0.994286258451576,
#   0.9912389296257499,
#   0.9879059137225026,
#   0.9862870202837825,
#   0.9960003809161032,
#   0.9989524807161223,
#   0.998571564612894,
#   0.9961908389677173,
#   0.9932387391676983,
#   0.9891438910579945,
#   0.9902866393676792,
#   0.9970479001999809,
#   0.995619464812875,
#   0.9903818683934863,
#   0.9943814874773831,
#   0.9987620226645081,
#   0.9920959908580135,
#   0.9973335872774022,
#   0.9991429387677364,
#   0.9950480906580326,
#   0.9923816779354347,
#   0.9960003809161032,
#   0.998666793638701,
#   0.9953337777354537,
#   0.9947624035806114,
#   0.9936196552709265,
#   0.9975240453290163,
#   0.9940958003999619,
#   0.9966669840967527,
#   0.9973335872774022,
#   0.9990477097419294,
#   0.9993333968193505,
#   0.9987620226645081,
#   0.9895248071612227,
#   0.9952385487096467,
#   0.9989524807161223,
#   0.9940958003999619,
#   0.9979049614322445,
#   0.9980001904580517,
#   0.9947624035806114,
#   0.9967622131225597,
#   0.9989524807161223,
#   0.9944767165031901,
#   0.9968574421483668,
#   0.9988572516903153,
#   0.9940005713741549,
#   0.9949528616322255,
#   0.9975240453290163,
#   0.9934291972193124,
#   0.9981906485096658,
#   0.9996190838967718,
#   0.9997143129225788,
#   0.9948576326064185,
#   0.9994286258451576,
#   0.999904770974193,
#   0.995619464812875,
#   0.9952385487096467,
#   0.9962860679935244,
#   0.9993333968193505,
#   0.9991429387677364,
#   1.0,
#   1.0,
#   1.0,
#   0.9868583944386249,
#   0.9977145033806304,
#   0.9982858775354728,
#   0.995524235787068,
#   0.9971431292257881,
#   0.9943814874773831,
#   0.9995238548709646,
#   0.9948576326064185,
#   0.9984763355870869,
#   0.999904770974193,
#   0.9963812970193315,
#   0.9988572516903153,
#   0.9984763355870869,
#   0.9993333968193505,
#   0.9992381677935435,
#   0.9984763355870869,
#   0.9951433196838396,
#   0.998666793638701],
#  'val_loss': [0.15034876963631674,
#   0.09576142599636858,
#   0.08330085959962823,
#   0.05760958527468822,
#   0.058249820159240205,
#   0.059760534365407444,
#   0.04626600365577774,
#   0.05251244203272191,
#   0.05433467027985237,
#   0.05315324233590879,
#   0.04647437433542853,
#   0.03782825467854061,
#   0.03737868006468158,
#   0.04375428983687677,
#   0.049873358675871386,
#   0.038337950956669045,
#   0.03998590341176499,
#   0.050004698446189814,
#   0.04269079436251724,
#   0.043656550409187644,
#   0.044108181819319726,
#   0.04255373930897225,
#   0.040989311443726445,
#   0.037579294679347765,
#   0.03316133588510142,
#   0.032557051887058396,
#   0.045684177331118424,
#   0.050799546886066145,
#   0.0395612630051222,
#   0.043609729068438435,
#   0.03179234366821633,
#   0.04066353114215996,
#   0.05443164555948566,
#   0.029335998440034348,
#   0.03254386461128227,
#   0.03719037105435167,
#   0.036540415358137,
#   0.029944404380777005,
#   0.03910347920927135,
#   0.03176947670078582,
#   0.03685934059956873,
#   0.02670938585764485,
#   0.03795249317084778,
#   0.04692092989148064,
#   0.032225857335354456,
#   0.03716695154170421,
#   0.039656223758885806,
#   0.03441398814902641,
#   0.039039877034057015,
#   0.02740523571172327,
#   0.02497750569944566,
#   0.033953308725242756,
#   0.04772824704308402,
#   0.03631393927789759,
#   0.030937356360002676,
#   0.03219576532044977,
#   0.03240101769545369,
#   0.0350911118153652,
#   0.03345919475223954,
#   0.03334840789585459,
#   0.031757945999164476,
#   0.0326286261477931,
#   0.034154951135331596,
#   0.03079228920938807,
#   0.05001891784962605,
#   0.038073119895786725,
#   0.035200000824195075,
#   0.03909884500952268,
#   0.030769013380631805,
#   0.02827645567330447,
#   0.028259814480869946,
#   0.03223540192517579,
#   0.027961573080127974,
#   0.02471287569159441,
#   0.04484715734777803,
#   0.043249725249849935,
#   0.03753126961475407,
#   0.028214723281350666,
#   0.02684632315543819,
#   0.022915009829342702,
#   0.023028279516703068,
#   0.024454109563058327,
#   0.0385751545492729,
#   0.029753948422148825,
#   0.03167004850428467,
#   0.031814246671274304,
#   0.029147693888278974,
#   0.032113892697221175,
#   0.02863082387696274,
#   0.030948933109439993,
#   0.03170725450459445,
#   0.026615792108085852,
#   0.033310914115281774,
#   0.028991511334474623,
#   0.032631778628406626,
#   0.026214311590460553,
#   0.026634113540587184,
#   0.029982819167939437,
#   0.03531172163731588,
#   0.03263880458173596],
#  'val_accuracy': [0.8491859468723222,
#   0.9160239931448158,
#   0.9005998286203942,
#   0.9208797486432447,
#   0.910025706940874,
#   0.908311910882605,
#   0.9243073407597829,
#   0.9248786061125392,
#   0.9188803199085975,
#   0.9245929734361611,
#   0.9168808911739503,
#   0.9297343616109683,
#   0.9357326478149101,
#   0.9028848900314196,
#   0.9314481576692374,
#   0.9374464438731791,
#   0.9354470151385319,
#   0.922879177377892,
#   0.9065981148243359,
#   0.9243073407597829,
#   0.9191659525849757,
#   0.9263067694944301,
#   0.934018851756641,
#   0.9354470151385319,
#   0.9471579548700372,
#   0.934018851756641,
#   0.9120251356755212,
#   0.9034561553841759,
#   0.922879177377892,
#   0.9285918309054556,
#   0.9357326478149101,
#   0.9360182804912882,
#   0.9057412167952014,
#   0.9380177092259354,
#   0.9285918309054556,
#   0.930876892316481,
#   0.9325906883747501,
#   0.9300199942873465,
#   0.8903170522707797,
#   0.9328763210511283,
#   0.9088831762353613,
#   0.943730362753499,
#   0.9263067694944301,
#   0.8940302770636961,
#   0.9320194230219937,
#   0.9303056269637247,
#   0.8920308483290489,
#   0.9334475864038846,
#   0.9280205655526992,
#   0.9374464438731791,
#   0.9411596686660954,
#   0.9174521565267066,
#   0.9085975435589831,
#   0.9317337903456155,
#   0.9380177092259354,
#   0.934018851756641,
#   0.9288774635818338,
#   0.9251642387889174,
#   0.9220222793487575,
#   0.9337332190802627,
#   0.9408740359897172,
#   0.9345901171093973,
#   0.9323050556983719,
#   0.9205941159668666,
#   0.8934590117109398,
#   0.9208797486432447,
#   0.927734932876321,
#   0.9208797486432447,
#   0.9383033419023136,
#   0.9403027706369609,
#   0.9380177092259354,
#   0.9323050556983719,
#   0.9357326478149101,
#   0.940588403313339,
#   0.9125964010282777,
#   0.9205941159668666,
#   0.9111682376463868,
#   0.9351613824621536,
#   0.9343044844330192,
#   0.9420165666952299,
#   0.9431590974007427,
#   0.93887460725507,
#   0.9220222793487575,
#   0.9363039131676664,
#   0.93887460725507,
#   0.9217366466723793,
#   0.921165381319623,
#   0.9337332190802627,
#   0.9303056269637247,
#   0.9345901171093973,
#   0.9351613824621536,
#   0.943730362753499,
#   0.9263067694944301,
#   0.93887460725507,
#   0.9257355041416738,
#   0.9177377892030848,
#   0.9345901171093973,
#   0.9305912596401028,
#   0.9285918309054556,
#   0.9363039131676664],
#  'model_name': 'Pretrained ResNet34',
#  'best_val_accuracy': 0.9471579548700372}

# %% [markdown]
# Let's plot the above matrices for visualization.

# %%
def plot_history(history):

    epochs = range(1, len(history['train_loss']) + 1)



    plt.figure(figsize=(12, 4))



    plt.subplot(1, 2, 1)

    plt.plot(epochs, history['train_loss'], label='Train Loss')

    plt.plot(epochs, history['val_loss'], label='Validation Loss')

    plt.xlabel('Epochs')

    plt.ylabel('Loss')

    plt.title('Train and Validation Loss')

    plt.legend()



    plt.subplot(1, 2, 2)

    plt.plot(epochs, history['train_accuracy'], label='Train Accuracy')

    plt.plot(epochs, history['val_accuracy'], label='Validation Accuracy')

    plt.xlabel('Epochs')

    plt.ylabel('Accuracy')

    plt.title('Train and Validation Accuracy')

    plt.legend()



    plt.show()



plot_history(history)

# %% [markdown]
# So from above we can see that our pre-trained model performs really good:
#
# * The training accuracy approaches 1.0 (100%) at the end of the training.
#
# * Wherelese, the validation accuracy fluctuates but ends around 0.93 (93%).

# %% [markdown]
# # Testing the model:-

# %% [markdown]
# **Let's first test our model on a single image picked randomly.**

# %%
# Load the best model

model.load_state_dict(torch.load(best_model_path))

model.eval()  # Set model to evaluation mode



# Create test loader (assumes a function `create_dataloader` exists)

test_loader = create_dataloader(loader_type='test')



# Evaluate model on the test set

test_correct = 0

test_total = 0



with torch.no_grad():  # Disable gradient calculation for testing

    for inputs, targets in test_loader:

        inputs, targets = inputs.to(device), targets.to(device)

        outputs = model(inputs)

        _, predicted = outputs.max(1)  # Get predictions

        test_total += targets.size(0)

        test_correct += predicted.eq(targets).sum().item()



test_accuracy = test_correct / test_total

print(f'Test Accuracy: {test_accuracy:.4f}')



# Choose a random image from the test loader and plot it

dataiter = iter(test_loader)

images, labels = next(dataiter)  # Use next() to get a batch



# Randomly select an image from the batch

random_index = np.random.randint(0, len(images))

image = images[random_index]

label = labels[random_index]



# Move the image to the appropriate device and make prediction

image_tensor = image.unsqueeze(0).to(device)

output = model(image_tensor)

_, predicted_class = output.max(1)



# Convert image to CPU and detach for plotting

image = image.cpu().numpy().transpose((1, 2, 0))  # Convert to numpy array for plotting

image = np.clip(image, 0, 1)  # Normalize pixel values for display



# Plot the image

plt.imshow(image)

plt.title(f'Predicted Class: {predicted_class.item()}, True Class: {label.item()}')

plt.show()



# Print the predicted class

print(f"Predicted Class: {predicted_class.item()}")

print(f"True Class: {label.item()}")
# Out:
# /tmp/ipykernel_23/3846559363.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# Test Accuracy: 0.9444
# Predicted Class: 1
# True Class: 1

# %% [markdown]
# **Now, let's test on a batch of images picked randomly.**

# %%
# Evaluate the model on a batch of test images

dataiter = iter(test_loader)

images, labels = next(dataiter)  # Get a batch of images and their labels



# Move images and labels to the appropriate device

images, labels = images.to(device), labels.to(device)



# Make predictions on the batch

outputs = model(images)

_, predicted_classes = outputs.max(1)



# Convert images back to CPU for visualization

images = images.cpu().numpy().transpose((0, 2, 3, 1))  # Convert to numpy array (N, H, W, C)

images = np.clip(images, 0, 1)  # Normalize pixel values for display



# Plot multiple images with their predicted and true labels

num_images_to_plot = 5  # Number of images to display

fig, axes = plt.subplots(1, num_images_to_plot, figsize=(15, 5))



for idx in range(num_images_to_plot):

    axes[idx].imshow(images[idx])

    axes[idx].set_title(

        f"Predicted: {predicted_classes[idx].item()}\nTrue: {labels[idx].item()}"

    )

    axes[idx].axis('off')



plt.tight_layout()

plt.show()



# Print predictions and true labels for the displayed images

for idx in range(num_images_to_plot):

    print(f"Image {idx + 1}:")

    print(f"    Predicted Class: {predicted_classes[idx].item()}")

    print(f"    True Class: {labels[idx].item()}")
# Out:
# Image 1:
#     Predicted Class: 1
#     True Class: 0
# Image 2:
#     Predicted Class: 5
#     True Class: 0
# Image 3:
#     Predicted Class: 0
#     True Class: 0
# Image 4:
#     Predicted Class: 0
#     True Class: 0
# Image 5:
#     Predicted Class: 0
#     True Class: 0
